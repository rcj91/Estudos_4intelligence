# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot


# fit an ARIMA model and plot residual errors
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot


from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
from pylab import rcParams

import matplotlib.pyplot as plt


import matplotlib.font_manager as font_manager
front_prop_small = font_manager.FontProperties(size=13)
font_prop = font_manager.FontProperties(size=16)
front_prop_big = font_manager.FontProperties(size=17)

# %matplotlib inline

import matplotlib.style
import matplotlib as mpl
print(plt.style.available) # see what styles are available

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML

from statsmodels.tsa.stattools import adfuller




import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
import statsmodels.api as sm

from statsmodels.regression.linear_model import OLS
import numpy as np

from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white

import statsmodels.api as sm
from statsmodels.formula.api import ols

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
#from yellowbrick.regressor import ResidualsPlot


from scipy import stats

import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
# Out:
# C:\Users\Rodrigo Cardozo\anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Rodrigo Cardozo\anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Data Analysis Skill Test
#
# 4intelligence
#
# General guidelines

# %% [markdown]
# •	The candidate must send us back a clean and reproducible code via github link in whatever coding language he/she chooses. Prefer notebooks: Rmarkdown for R and Jupyter for Python. We should be able to reproduce any result you migh want to show us
#
# •	Due date: 08/07/2020 [Wednesday by 5 PM]
#
# •	Reach us at vagas@4intelligence.com.br

# %% [markdown]
# # Case 1

# %% [markdown]
# •	Open the TFP.csv file attached.
#
# •	The series is composed by TFP (rtfpna variable) at constant national prices (2005 = 1) for three countries: United States (USA), Canada (CAN) and Mexico (MEX).
#
# 1.	Make an exploratory data analysis;
# 2.	Forecast 10 years of the series (if you are performing the exercise in R, use package “forecast”);
# 3.	Check in the following link pages 2 and 3: https://cran.r-project.org/web/packages/pwt8/pwt8.pdf to see a list of all variables in the original dataset. Can you think about another feature that could be helpful in explaining TFP series? Explain.

# %% [markdown]
# ### 1. Exploratory data analysis

# %% [markdown]
# DATASETS

# %%
TFP = pd.read_csv('TFP.csv', sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
TFP.head()
# Out:
#   isocode  year    rtfpna
# 0     USA  1950  0.617148
# 1     USA  1951  0.629588
# 2     USA  1952  0.638451
# 3     USA  1953  0.651858
# 4     USA  1954  0.646179

# %% [markdown]
# Filtros

# %%
USA = TFP[TFP['isocode'] == 'USA']
USA['year'] = USA['year'].astype(int)
USA['year'] = pd.to_datetime(USA['year'] ,format='%Y')
USA = USA.set_index('year')
USA = USA[['rtfpna']]
#USA = USA.iloc[:,1] 

CAN = TFP[TFP['isocode'] == 'CAN']
CAN['year'] = CAN['year'].astype(int)
CAN['year'] = pd.to_datetime(CAN['year'] ,format='%Y')
CAN = CAN.set_index('year')
CAN = CAN[['rtfpna']]
#CAN = CAN.iloc[:,1] 

MEX = TFP[TFP['isocode'] == 'MEX']
MEX['year'] = MEX['year'].astype(int)
MEX['year'] = pd.to_datetime(MEX['year'] ,format='%Y')
MEX = MEX.set_index('year')
MEX = MEX[['rtfpna']]
#MEX = MEX.iloc[:,1] 

TFP['Year'] = TFP['year']
TFP['year'] = pd.to_datetime(TFP['year'], format='%Y')
TFP = TFP.set_index('year')

TFP.isocode.value_counts()
# Out:
# USA    62
# CAN    62
# MEX    62
# Name: isocode, dtype: int64

# %% [markdown]
# No gráfico abaixo é apresentado as médias dos valores de TFP para cada um dos três países. Podemos notar que o México  possui a maior média comparado aos outros dois países. Isso pois houve um crescimento muito forte no começo dos anos 50 que ficou conhecido como o Milagre Mexicano. Isso será mostrado mais adiante. como será mostrado mais adiante.

# %%
fig,ax = plt.subplots(figsize=(15, 8)) 

TFP.groupby('isocode')['rtfpna'].mean().plot.barh()

plt.title('Média dos valores de TFP para cada um dos países', size=20, pad=15)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('TFP', fontsize=20, labelpad=20)
plt.ylabel('', fontsize=20, labelpad=20);

# %% [markdown]
# Histograma da variável resposta 'rtfpna'. Notamos que os valores mais frequentes estão centralizados próximos ao valor 1,0.

# %%
fig, ax = plt.subplots(figsize=(20, 10))


plt.hist(TFP['rtfpna'], bins='auto', alpha=0.7, rwidth=0.85)
plt.title(" Histograma da variável 'rtfpna' ", size=20, pad=15)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Frequência', fontsize=20, labelpad=20);



fig, ax = plt.subplots(figsize=(20, 10))
TFP['rtfpna'].plot(kind='kde')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Densidade', fontsize=20, labelpad=20);

pyplot.show()

# %% [markdown]
# ### Histograma - USA

# %% [markdown]
# Filtrando os dados para o USA percebemos uma distribuição bicaudal com valores frequentes em torno de 0.75 e 1.0.

# %%
fig, ax = plt.subplots(figsize=(20, 10))


plt.hist(USA['rtfpna'], bins='auto', alpha=0.7, rwidth=0.85)


plt.title(" Histograma da variável 'rtfpna' para os USA ", size=20, pad=15)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Frequência', fontsize=20, labelpad=20);

fig, ax = plt.subplots(figsize=(20, 10))
USA['rtfpna'].plot(kind='kde')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Densidade', fontsize=20, labelpad=20);

pyplot.show()

# %% [markdown]
# ### CANADA

# %% [markdown]
# Filtrando os dados para o Canada podemos perceber uma distribuição normal enviesada para a esquerda com valores frequentes centralizados em torno de 1.0

# %%
fig, ax = plt.subplots(figsize=(20, 10))

plt.hist(CAN['rtfpna'], bins='auto', alpha=0.7, rwidth=0.85)

plt.title(" Histograma da variável 'rtfpna' para o Canada ", size=20, pad=15)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Frequência', fontsize=20, labelpad=20);

fig, ax = plt.subplots(figsize=(20, 10))
CAN['rtfpna'].plot(kind='kde')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Densidade', fontsize=20, labelpad=20);

pyplot.show()

# %% [markdown]
# ### MÉXICO

# %% [markdown]
# Em relação ao México notamos uma distribuição bicaudal com valores frequentes centralizados em 1.1 e 1.3.

# %%
fig, ax = plt.subplots(figsize=(20, 10))

plt.hist(MEX['rtfpna'], bins='auto', alpha=0.7, rwidth=0.85)


plt.title(" Histograma da variável 'rtfpna' para o México ", size=20, pad=15)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Frequência', fontsize=20, labelpad=20);



fig, ax = plt.subplots(figsize=(20, 10))
MEX['rtfpna'].plot(kind='kde')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Densidade', fontsize=20, labelpad=20);

pyplot.show()

# %% [markdown]
# ### Gráfico de Linha para a observação do comportamento da variável TFP ao longo do tempo.

# %% [markdown]
# México: Os valores de TFP do México cresceram muito entre meados dos anos 50 até o começo dos anos 80. Havendo uma queda nos anos 80. A curva se encontra abaixo de 1 no final da série com uma tendência de recuperação no final da série.
#
# Canada: Os valores do Canada se mantiveram quase que estáveis ao longo do tempo, permanecendo com quase o mesmo valor no final da série temporal. Houve uma tendência de queda na última década da série com uma leve recuperação.
#
# USA: Os USA mantiveram uma tendência de crescimento ao longo da série.

# %%
plt.figure(figsize=(20,10))

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'USA'].query('1950 < year <= 2011'),marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=3,label="USA");

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'CAN'].query('1950 < year <= 2011'),marker='', color='red', linewidth=3,label="CAN");

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'MEX'].query('1950 < year <= 2011'), marker='', color='green', linewidth=3,  label="MEX");

plt.title("Valores TFP ao longo dos anos", size=20, pad=15)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Anos', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP ', fontsize=20, labelpad=20);

plt.legend(fontsize=20)

plt.show()

# %% [markdown]
# ### Gráficos Box Plot

# %% [markdown]
# Canada: Possui os dados mais próximos da mediana, em torno do valor 1
# (que é próximo ao valor base,  2005 = 1 ) com pouca variação. Há presença de alguns outliers.
#
# México: Possui uma maior variação nos seus dados, com a maior parte acima da mediana, que é em torno de 1.1. (2005 = 1)
#
# USA: Possui a menor mediana em comparação dos outros países, em torno de 0.7 (2005 = 1 ). A maior parte dos dados está na região acima da mediana (75%).

# %%
plt.figure(figsize=(20,10))


sns.boxplot(data=TFP, y='rtfpna', x='isocode')

plt.title('Box Plot da distribuição dos valores de TFP', size=20, pad=15)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valores TFP', fontsize=20, labelpad=20);

# %% [markdown]
# ### Box Plot dividido por décadas.

# %% [markdown]
# Nessa etapa dividimos os valores por décadas para observarmos o comportamento da distribuição da variável TFP para cada país.

# %%
fig,ax = plt.subplots(figsize=(15, 8)) 


sns.boxplot(data=TFP.query('1950 < year <= 1960'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP (Década de 50 a 60)', size=20, pad=15)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Anos', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %%
fig,ax = plt.subplots(figsize=(15, 8)) 


sns.boxplot(data=TFP.query('1960 < year <= 1970'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP  (Década de 60 a 70)', size=20, pad=15)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %% [markdown]
# Nas décadas de 50 até o final da década de 70 notamos um aumento na distribuição da variável TFP do México, o que está de acordo com o gráfico de linha mostrado anteriormente.

# %%
# Boxplot


fig,ax = plt.subplots(figsize=(15, 8)) 


sns.boxplot(data=TFP.query('1970< year <= 1980'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP (Década de 70 a 80)', size=20, pad=15)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %%
# Boxplot


fig,ax = plt.subplots(figsize=(15, 8)) 


sns.boxplot(data=TFP.query('1980 < year <= 1990'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP  (Década de 80 a 90)', size=20, pad=15)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %% [markdown]
# Entre as décadas de 70 e 90 notamos uma queda na distribuição da variável do México e uma estabilidade do valor TFP para todos os países na década de 70 a 80.

# %%
# Boxplot


fig,ax = plt.subplots(figsize=(15, 8)) 


sns.boxplot(data=TFP.query('1990 < year <= 2000'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP  (Década de 90 a 2000)', size=20, pad=15)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %% [markdown]
# No final da série temporal notamos uma certa estabilidade dos USA e uma distribuição maior abaixo da mediana no país Canada.

# %%
# Boxplot

# definindo o tamanho do gráfico
fig,ax = plt.subplots(figsize=(15, 8)) 

#  plotando apenas indenizações até R$ 70.000,00 que são diferentes de 0
sns.boxplot(data=TFP.query('2000 < year <= 2011'), y='rtfpna', x='isocode');


plt.title('Box Plot da distribuição dos valores de TFP  (Década de 2000 a 2010)', size=20, pad=15)

plt.xlabel('Países', fontsize=20, labelpad=20)
plt.ylabel('Valor TFP', fontsize=20, labelpad=20);

plt.xlabel('');

# %% [markdown]
# ### Análise das LAGs para cada um dos países.

# %% [markdown]
# O gráfico criado mostra uma correlação positiva relativamente forte entre as observações e seus valores de atraso. Além disso não notamos valores outliers. Por fim, a forma linear dos gráficos sugerem que um modelo autorregressivo é provavelmente uma escolha melhor.

# %%
##########################################################################
plt.figure(figsize=(20,10))
plt.title('Gráfico de dispersão para todos os dados (sem filtro)', size=20, pad=15)
plt.xlabel('Years', fontsize=20, labelpad=20)
plt.ylabel('TFP Value', fontsize=20, labelpad=20);
lag_plot(TFP['rtfpna'])


#########################################################################
plt.figure(figsize=(20,10))
plt.title('Gráfico de dispersão da análise de lag para os USA', size=20, pad=15)
plt.xlabel('Years', fontsize=20, labelpad=20)
plt.ylabel('TFP Value', fontsize=20, labelpad=20);
lag_plot(TFP[TFP['isocode'] == 'USA']['rtfpna'])
pyplot.show()

#########################################################################
plt.figure(figsize=(20,10))
lag_plot(TFP[TFP['isocode'] == 'CAN']['rtfpna'])
plt.title('Gráfico de dispersão da análise de lag para o Canada', size=20, pad=15)
plt.xlabel('Years', fontsize=20, labelpad=20)
plt.ylabel('TFP Value', fontsize=20, labelpad=20);
lag_plot(TFP[TFP['isocode'] == 'CAN']['rtfpna'])
pyplot.show()

#########################################################################
plt.figure(figsize=(20,10))
lag_plot(TFP[TFP['isocode'] == 'MEX']['rtfpna'])
plt.title('Gráfico de dispersão da análise de lag para o México', size=20, pad=15)
plt.xlabel('Years', fontsize=20, labelpad=20)
plt.ylabel('TFP Value', fontsize=20, labelpad=20);
lag_plot(TFP[TFP['isocode'] == 'MEX']['rtfpna'])
pyplot.show()

# %% [markdown]
# ### Decomposição das séries para cada um dos países

# %% [markdown]
# ### USA

# %% [markdown]
# Notamos uma tendência de crescimento na série dos USA, como pode ser observado no segundo gráfico logo abaixo.

# %%
rcParams['figure.figsize'] = 10, 10
decomposition = sm.tsa.seasonal_decompose(TFP[TFP['isocode'] == 'USA']['rtfpna'], model='additive',period = 31)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### CANADA

# %% [markdown]
# Notamos uma tendência de queda na série do Canada.

# %%
rcParams['figure.figsize'] = 10, 10
decomposition = sm.tsa.seasonal_decompose(TFP[TFP['isocode'] == 'CAN']['rtfpna'], model='additive',period = 31)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Mexico

# %% [markdown]
# Notamos uma tendência de queda na série do México.

# %%
rcParams['figure.figsize'] = 10, 10
decomposition = sm.tsa.seasonal_decompose(TFP[TFP['isocode'] == 'MEX']['rtfpna'], model='additive',period = 31)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # 2. Forecast

# %% [markdown]
# Aqui vamos apresentar uma previsão para a série TFP dos três países em questão. Vale mencionar que essas previsões não levam em consideração fatos do futuro, pois isso seria impossível, elas são baseadas em dados históricos. A previsão foi dividida para cada um dos países.

# %% [markdown]
# ### USA

# %%
#Filtro para os USA

USA = TFP[TFP['isocode'] == 'USA']
USA['Year'] = USA['Year'].astype(int)
USA['Year'] = pd.to_datetime(USA['Year'] ,format='%Y')
USA = USA.set_index('Year')
USA = USA[['rtfpna']]

# %% [markdown]
# Teste de hipótese para sabermos se a serie é estaciónaria ou não estacionára.

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("Evidência forte contra a hipótese nula (Ho), rejeite a hipótese nula. Os dados são estacionários")
    else:
        print(" Evidência fraca contra a hipótese nula, indicando que é não estacionária")

adfuller_test(USA['rtfpna'])
# Out:
# ADF Test Statistic : 0.22364656429890467
# p-value : 0.9735571048602328
# #Lags Used : 0
# Number of Observations : 61
#  Evidência fraca contra a hipótese nula, indicando que é não estacionária

# %% [markdown]
# Atraves do gráfico abaixo podemos observar uma fraca sazonalidade e que há uma autocerralação na variável TFP

# %%
plt.figure(figsize=(20,10))

autocorrelation_plot(TFP[TFP['isocode'] == 'USA']['rtfpna'])
plt.title('Autocorrelation (TFP USA)', size=20, pad=15)
plt.ylabel('Autocorrelation',fontsize=20)
plt.xlabel('Lag',fontsize=20)

pyplot.show()

# %% [markdown]
# Montando o modelo ARIMA para a série dos USA

# %% [markdown]
# Usamos um grid search para selecionar os melhores hiper parâmetros (p,d,q) para o modelo ARIMA.
#
# p: O número de observações de defasagem incluídas no modelo, também chamado de ordem de defasagem.
#
# d: O número de vezes que as observações brutas são diferenciadas, também chamado de grau de diferenciação.
#
# q: O tamanho da janela da média móvel, também chamada de ordem da média móvel.
#
# Os melhores hiper parâmetros ARIMA são p: 0, d: 2, q: 2 com um RMSE de 0,010.
#  Foi usado 66% dos dados para treino e 34% para teste.

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(USA.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=0.180
# ARIMA(0, 0, 1) RMSE=0.095
# ARIMA(0, 0, 2) RMSE=0.060
# ARIMA(0, 1, 0) RMSE=0.013
# ARIMA(0, 1, 1) RMSE=0.012
# ARIMA(0, 1, 2) RMSE=0.012
# ARIMA(0, 2, 0) RMSE=0.012
# ARIMA(0, 2, 1) RMSE=0.010
# ARIMA(0, 2, 2) RMSE=0.010
# ARIMA(1, 0, 0) RMSE=0.013
# ARIMA(1, 0, 1) RMSE=0.012
# ARIMA(1, 0, 2) RMSE=0.012
# ARIMA(1, 1, 0) RMSE=0.012
# ARIMA(1, 1, 1) RMSE=0.010
# ARIMA(1, 1, 2) RMSE=0.011
# ARIMA(1, 2, 0) RMSE=0.011
# ARIMA(1, 2, 1) RMSE=0.010
# ARIMA(1, 2, 2) RMSE=0.010
# ARIMA(2, 0, 0) RMSE=0.012
# ARIMA(2, 0, 1) RMSE=0.013
# ARIMA(2, 0, 2) RMSE=0.012
# ARIMA(2, 1, 0) RMSE=0.011
# ARIMA(2, 1, 1) RMSE=0.010
# ARIMA(2, 1, 2) RMSE=0.011
# ARIMA(2, 2, 0) RMSE=0.011
# ARIMA(2, 2, 1) RMSE=0.010
# ARIMA(2, 2, 2) RMSE=0.010
# ARIMA(4, 0, 0) RMSE=0.013
# ARIMA(4, 0, 1) RMSE=0.012
# ARIMA(4, 0, 2) RMSE=0.012
# ARIMA(4, 1, 0) RMSE=0.011
# ARIMA(4, 1, 1) RMSE=0.011
# ARIMA(4, 1, 2) RMSE=0.010
# ARIMA(4, 2, 0) RMSE=0.010
# ARIMA(4, 2, 1) RMSE=0.010
# ...

# %% [markdown]
# Nesta parte foi usamos os melhores hiper parâmetros para a criação do modelo ARIMA. Os resultados completos são mostrados na célula abaixo.

# %%
mod = sm.tsa.statespace.SARIMAX(USA,
                                order=(0, 2, 2),
                                seasonal_order=(0, 2, 2, 5),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8051      0.186     -4.339      0.000      -1.169      -0.441
# ma.L2         -0.1249      0.199     -0.628      0.530      -0.515       0.265
# ma.S.L5       -1.2942      0.908     -1.425      0.154      -3.075       0.486
# ma.S.L10       0.3329      0.316      1.055      0.291      -0.286       0.951
# sigma2         0.0002      0.000      1.140      0.254      -0.000       0.001
# ...

# %% [markdown]
# ### Previsão  em cima de valores já observados entre 2000 e 2010

# %% [markdown]
# No gráfico abaixo observa-se que o modelo acertou a tendência de crescimento da serie e se ajustou bem na linha observada com um erro muito pequeno.

# %%
pred = results.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = USA['1950':].plot(label='', marker='o')

pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 7), marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

plt.title('Forecast (TFP Canada)', size=20, pad=15)
ax.set_xlabel('Anos',fontsize=20)
ax.set_ylabel('Valor TFP',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend();

# %% [markdown]
# ### Previsão em 10 anos no futuro

# %% [markdown]
# No gráfico abaixo podemos observar uma tendência de crescimento nos próximos 10 anos com os erros para mais e para menos sendo representados pela área mais escura. Isso está em total concordância com a tendência de crescimento do passado da série temporal.

# %%
#fig, ax = plt.subplots(figsize=(20, 10))

pred_uc = results.get_forecast(steps=10, marker='o')
pred_ci = pred_uc.conf_int()

ax = USA.plot(label='Valor observado', figsize=(14, 7), marker='o')
pred_uc.predicted_mean.plot(ax=ax, label='Forecast', marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Anos')
ax.set_ylabel('TFP',fontsize=10)
plt.legend()

plt.title('Forecast (TFP Canada) 10 anos no futuro', size=20, pad=15)

plt.yticks(fontsize=10);
           


plt.xticks(fontsize=10)



plt.show()

# %% [markdown]
# ### CANADA

# %%
#Filtro para os USA

CAN = TFP[TFP['isocode'] == 'CAN']
CAN['Year'] = CAN['Year'].astype(int)
CAN['Year'] = pd.to_datetime(CAN['Year'] ,format='%Y')
CAN = CAN.set_index('Year')
CAN = CAN[['rtfpna']]
#USA = USA.iloc[:,1]

# %% [markdown]
# Teste de hipótese para sabermos se a serie é estaciónaria ou não estacionára.

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("Evidência forte contra a hipótese nula (Ho), rejeite a hipótese nula. Os dados são estacionários")
    else:
        print("Evidência fraca contra a hipótese nula, indicando que é não estacionária ")

adfuller_test(CAN['rtfpna'])
# Out:
# ADF Test Statistic : -3.0277534183067387
# p-value : 0.032382616614812565
# #Lags Used : 1
# Number of Observations : 60
# Evidência forte contra a hipótese nula (Ho), rejeite a hipótese nula. Os dados são estacionários

# %% [markdown]
# Podemos observar uma fraca sazonalidade entre os dados.

# %%
plt.figure(figsize=(20,10))

autocorrelation_plot(TFP[TFP['isocode'] == 'CAN']['rtfpna'])
plt.title('Autocorrelation (TFP CAN)', size=20, pad=15)
plt.ylabel('Autocorrelation',fontsize=20)
plt.xlabel('Lag',fontsize=20)
pyplot.show()

# %% [markdown]
# Os melhores hiper parâmetros são p:1, d:0, q:1 com um RMSE de 0.014. Também foi usado 66% dos dados para treino e 34% para teste.

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(CAN.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=0.038
# ARIMA(0, 0, 1) RMSE=0.023
# ARIMA(0, 0, 2) RMSE=0.019
# ARIMA(0, 1, 0) RMSE=0.016
# ARIMA(0, 1, 1) RMSE=0.014
# ARIMA(0, 1, 2) RMSE=0.015
# ARIMA(0, 2, 0) RMSE=0.016
# ARIMA(0, 2, 1) RMSE=0.016
# ARIMA(0, 2, 2) RMSE=0.014
# ARIMA(1, 0, 0) RMSE=0.016
# ARIMA(1, 0, 1) RMSE=0.014
# ARIMA(1, 0, 2) RMSE=0.015
# ARIMA(1, 1, 0) RMSE=0.015
# ARIMA(1, 1, 1) RMSE=0.015
# ARIMA(1, 1, 2) RMSE=0.015
# ARIMA(1, 2, 0) RMSE=0.015
# ARIMA(1, 2, 1) RMSE=0.015
# ARIMA(1, 2, 2) RMSE=0.015
# ARIMA(2, 0, 0) RMSE=0.014
# ARIMA(2, 0, 1) RMSE=0.015
# ARIMA(2, 0, 2) RMSE=0.015
# ARIMA(2, 1, 0) RMSE=0.015
# ARIMA(2, 1, 1) RMSE=0.016
# ARIMA(2, 1, 2) RMSE=0.018
# ARIMA(2, 2, 0) RMSE=0.017
# ARIMA(2, 2, 1) RMSE=0.016
# ARIMA(2, 2, 2) RMSE=0.016
# ARIMA(4, 0, 0) RMSE=0.015
# ARIMA(4, 0, 1) RMSE=0.016
# ARIMA(4, 0, 2) RMSE=0.016
# ARIMA(4, 1, 0) RMSE=0.016
# ARIMA(4, 1, 1) RMSE=0.016
# ARIMA(4, 1, 2) RMSE=0.017
# ARIMA(4, 2, 0) RMSE=0.017
# ARIMA(4, 2, 1) RMSE=0.016
# ...

# %% [markdown]
# Os resultados mais completos são encontrados logo abaixo

# %%
mod = sm.tsa.statespace.SARIMAX(CAN,
                                order=(1, 0, 1),
                                seasonal_order=(1, 0, 1, 5),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8233      0.094      8.759      0.000       0.639       1.008
# ma.L1          0.4383      0.180      2.432      0.015       0.085       0.791
# ar.S.L5        0.9943      0.009    107.599      0.000       0.976       1.012
# ma.S.L5       -1.0001    259.693     -0.004      0.997    -509.990     507.990
# sigma2         0.0003      0.078      0.004      0.997      -0.152       0.153
# ...

# %% [markdown]
# ### Previsão  em cima de valores já observados entre 2000 e 2010

# %% [markdown]
# No gráfico abaixo podemos observar que o modelo acertou a tendência de queda da serie e se ajustou bem na linha observada com um erro muito pequeno.

# %%
pred = results.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = CAN['1950':].plot(label='', marker='o')

pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 7), marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

plt.title('Forecast (TFP Canada)', size=20, pad=15)
ax.set_xlabel('Years',fontsize=20)
ax.set_ylabel('TFP',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend();

# %% [markdown]
# ### Previsão para 10 anos no futuro

# %% [markdown]
# Podemos observar uma leve tendencia de crescimento por volta do ano de 2010 e uma tendencia de estabilidade no final no ano de 2019 e começo de 2020.

# %%
#fig, ax = plt.subplots(figsize=(20, 10))

pred_uc = results.get_forecast(steps=10, marker='o')
pred_ci = pred_uc.conf_int()

ax = CAN.plot(label='Valor observado', figsize=(14, 7), marker='o')
pred_uc.predicted_mean.plot(ax=ax, label='Previsão', marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Anos')
ax.set_ylabel('TFP',fontsize=10)
plt.legend()



plt.yticks(fontsize=10);
           


plt.xticks(fontsize=10)



plt.show()

# %% [markdown]
# ### MÉXICO

# %%
#Filtro para os USA

MEX = TFP[TFP['isocode'] == 'MEX']
MEX['Year'] = MEX['Year'].astype(int)
MEX['Year'] = pd.to_datetime(MEX['Year'] ,format='%Y')
MEX = MEX.set_index('Year')
MEX = MEX[['rtfpna']]
#MEX = MEX.iloc[:,1]

# %% [markdown]
# Teste de hipótese para sabermos se a série é estacionaria ou não estacionara.

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("Evidência forte contra a hipótese nula (Ho), rejeite a hipótese nula. Os dados são estacionários")
    else:
        print("Evidência fraca contra a hipótese nula, indicando que é não estacionária ")

adfuller_test(MEX['rtfpna'])
# Out:
# ADF Test Statistic : -1.9404439845753265
# p-value : 0.31328057628857175
# #Lags Used : 9
# Number of Observations : 52
# Evidência fraca contra a hipótese nula, indicando que é não estacionária

# %% [markdown]
# Podemos observar uma fraca sazonalidade entre os dados.

# %%
plt.figure(figsize=(20,10))

autocorrelation_plot(TFP[TFP['isocode'] == 'MEX']['rtfpna'])
plt.title('Autocorrelation (TFP MEX)', size=20, pad=15)
plt.ylabel('Autocorrelation',fontsize=20)
plt.xlabel('Lag',fontsize=20)
pyplot.show()

# %% [markdown]
# Os melhores hiper parâmetros são p:1, d:0, q:0 com RMSE de 0.027. Também foi usado 66% dos dados para treino e 34% para teste.

# %%
MEX
# Out:
#               rtfpna
# Year
# 1950-01-01  0.798159
# 1951-01-01  0.860931
# 1952-01-01  0.876968
# 1953-01-01  0.855204
# 1954-01-01  0.929168
# ...              ...
# 2007-01-01  1.013673
# 2008-01-01  0.991548
# 2009-01-01  0.915879
# 2010-01-01  0.941604
# 2011-01-01  0.955766
#
# [62 rows x 1 columns]

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(MEX.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=0.141
# ARIMA(0, 0, 1) RMSE=0.081
# ARIMA(0, 0, 2) RMSE=0.053
# ARIMA(0, 1, 0) RMSE=0.028
# ARIMA(0, 1, 1) RMSE=0.029
# ARIMA(0, 1, 2) RMSE=0.029
# ARIMA(0, 2, 0) RMSE=0.038
# ARIMA(0, 2, 1) RMSE=0.030
# ARIMA(0, 2, 2) RMSE=0.030
# ARIMA(1, 0, 0) RMSE=0.027
# ARIMA(1, 0, 1) RMSE=0.028
# ARIMA(1, 0, 2) RMSE=0.029
# ARIMA(1, 1, 0) RMSE=0.029
# ARIMA(1, 1, 1) RMSE=0.029
# ARIMA(1, 1, 2) RMSE=0.029
# ARIMA(1, 2, 0) RMSE=0.036
# ARIMA(1, 2, 1) RMSE=0.031
# ARIMA(1, 2, 2) RMSE=0.028
# ARIMA(2, 0, 0) RMSE=0.029
# ARIMA(2, 0, 1) RMSE=0.030
# ARIMA(2, 0, 2) RMSE=0.048
# ARIMA(2, 1, 0) RMSE=0.029
# ARIMA(2, 1, 1) RMSE=0.029
# ARIMA(2, 1, 2) RMSE=0.029
# ARIMA(2, 2, 0) RMSE=0.034
# ARIMA(2, 2, 1) RMSE=0.030
# ARIMA(2, 2, 2) RMSE=0.031
# ARIMA(4, 0, 0) RMSE=0.030
# ARIMA(4, 0, 1) RMSE=0.030
# ARIMA(4, 0, 2) RMSE=0.033
# ARIMA(4, 1, 0) RMSE=0.031
# ARIMA(4, 1, 1) RMSE=0.031
# ARIMA(4, 1, 2) RMSE=0.030
# ARIMA(4, 2, 0) RMSE=0.034
# ARIMA(4, 2, 1) RMSE=0.030
# ...

# %% [markdown]
# Nesta etapa foi usado os melhores hiper parâmetros selecionados logo acima para a criação do modelo ARIMA. Os resultados completos são mostrados na célula abaixo.

# %%
mod = sm.tsa.statespace.SARIMAX(MEX,
                                order=(1, 0, 0),
                                seasonal_order=(1, 0, 0, 10),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9954      0.005    183.220      0.000       0.985       1.006
# ar.S.L10       0.1460      0.141      1.036      0.300      -0.130       0.422
# sigma2         0.0011      0.000      5.614      0.000       0.001       0.001
# ...

# %% [markdown]
# ## Previsão em cima de valores já observados entre 2000 e 2010

# %% [markdown]
# Observa-se que o modelo acertou a tendência de queda da série e se ajustou bem na linha observada com um erro muito pequeno.

# %%
pred = results.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = MEX['1950':].plot(label='Valor observado', marker='o')

pred.predicted_mean.plot(ax=ax, label='Previsão 10 anos', alpha=.7, figsize=(14, 7), marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Anos')
ax.set_ylabel('TFP',fontsize=10)
plt.legend()
;
# Out:
# ''

# %% [markdown]
# ## Previsão para os próximos 10 anos no futuro

# %% [markdown]
# Podemos observar que a previsão acompanhou a tendência de queda da série. Podemos observar também uma leve estabilidade no final da década em questão.

# %%
#fig, ax = plt.subplots(figsize=(20, 10))

pred_uc = results.get_forecast(steps=10, marker='o')
pred_ci = pred_uc.conf_int()

ax = MEX.plot(label='Valor observado', figsize=(14, 7), marker='o')
pred_uc.predicted_mean.plot(ax=ax, label='Previsão', marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Anos')
ax.set_ylabel('TFP',fontsize=10)
plt.legend()



plt.yticks(fontsize=10);
           


plt.xticks(fontsize=10)



plt.show()

# %% [markdown]
# # 3. Can you think about another feature that could be helpful in explaining TFP series? Explain.

# %%
plt.figure(figsize=(20,10))

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'USA'].query('1950 < year <= 2011'),marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=3,label="USA");

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'CAN'].query('1950 < year <= 2011'),marker='', color='red', linewidth=3,label="CAN");

plt.plot('Year','rtfpna', data=TFP[TFP['isocode'] == 'MEX'].query('1950 < year <= 2011'), marker='', color='green', linewidth=3,  label="MEX");


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Years', fontsize=20, labelpad=20)
plt.ylabel('TFP Value', fontsize=20, labelpad=20);

plt.legend(fontsize=20)

plt.show()

# %% [markdown]
# Resposta:

# %% [markdown]
# O México implementou iniciativas similares a substituição de importações, o que fomentou o desenvolvimento da indústria interna e isso pode explicar parte do aumento da produtividade dos fatores do período entre 60/80. Para avaliar esses impactos poderemos analisar duas variáveis. Primeiro, comportamento do preço das importações *pl_m* (Price level of imports (price level of USA GDPo in 2005 = 1). Espera -se que o preço das importações se mantenha elevado ao longo do período (60/80), caracterizando uma política de substituição de exportações. Em segundo lugar espera-se que a participação do consumo interno no PIB (Produto interno bruto) também se mantenha elevada ao longo do período, como consequência da substituição de importações. *csh_c* (share de participação do consumo doméstico)
#
# Além disso, pelo lado da mão de obra houve investimento massivo em educação. Espera-se que isso resulte em maior nível de qualificação da mão de obra aumentando a produtividade desse fator.  com fluxo de mão de obra disponíveis e investimento passivo em educação, o que explica a contribuição da mão de obra para o aumento da produtividade dos fatores. A variável *hc* (Index of human capital per person, based on years of schooling (Barro and Lee 2013) and returns to education (Psacharopoulos 1994)) corroboraria com a confirmação ou não do crescimento da produtividade entre os anos 60/80.
#
# Outra variável relevante é a quantidade de horas trabalhadas *avh* (Average annual hours worked by persons engaged). Espera-se que essa grandeza cresça menos que proporcionalmente que a produção total, caracterizando o incremento na produtividade dos fatores observado na série histórica do México entre os anos 1960 e 1980.
#
# USA/Canada: A tendência de crescimento do TFP americano e canadense se manteve estável ao longo dos anos, isso se deve a uma estrutura interna desenvolvida com um estoque de capital elevada e uma força de trabalho de alto nível
# *hc* (Index of human capital per person, based on years of schooling (Barro and Lee 2013) and returns
# to education (Psacharopoulos 1994)). Comparando um estoque de capital e o Capital humano com dos outros dois países espera-se que apresente a tendência de permanecer relativamente mais elevado ao longo dos anos. ck Capital stock at current PPPs (in million 2005 USD).

# %% [markdown]
# # Case 2

# %% [markdown]
# •	Attached to this test is a .csv file which contains data from Comexstat, which is basically the official data source for brazilian exports e imports, maintened by the government;
#
# •	The dataset contains all trackings of monthly imports and exports of a range of products (soybeans, soybean meal, soybean oil, corn, wheat and sugar), by brazilian states, by routes (air, sea, ground, etc) e from/to which country;
#
# •	We ask you to address a couple quentions below. Remember that data viz is one important skill to show besides any analytical skill. So we encourage you to use and explore a bunch of graphs and tables to show your point.
#
# 1.	Show the evolution of total monthly and total annual exports from Brazil (all states and to everywhere) of ‘soybeans’, ‘soybean oil’ and ‘soybean meal’;
# 2.	What are the 3 most important products exported by Brazil in the last 5 years?
# 3.	What are the main routes through which Brazil have been exporting ‘corn’ in the last few years? Are there differences in the relative importancem of routes depending on the product?
# 4.	Which countries have been the most important trade partners for Brazil in terms of ‘corn’ and ‘sugar’ in the last 3 years?
# 5.	For each of the products in the dataset, show the 5 most important states in terms of exports?
# 6.	Now, we ask you to show your modelling skills. Feel free to use any type of modelling approach, but bear in mind that the modelling approach depends on the nature of your data, and so different models yield different estimates and forecasts. To help you out in this task we also provide you with a dataset of possible covariates (.xlsx). They all come from public sources (IMF, World Bank) and are presented in index number format. Question: What should be the total brazilian soybeans, soybean_meal, and corn export forecasts, in tons, for the next 11 years (2020-2030)? We’re mostly interested in the annual forecast.

# %% [markdown]
# Preparando dadaset

# %%
covariates = pd.read_excel('covariates.xlsx', sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True)
comexsta = pd.read_csv('data_comexstat.csv', sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding='latin-1', dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
comexsta.head()
# Out:
#          date product state        country    type   route    tons       usd
# 0  1997-01-01    corn    ES  United States  Import     Sea  44.045  113029.0
# 1  1997-01-01    corn    GO      Argentina  Import  Ground  54.000   36720.0
# 2  1997-01-01    corn    GO        Bolivia  Export  Ground   0.200     180.0
# 3  1997-01-01    corn    GO  United States  Export     Sea   3.488    5688.0
# 4  1997-01-01    corn    MG      Argentina  Import  Ground  27.000   18630.0

# %% [markdown]
# ## 1. Show the evolution of total monthly and total annual exports from Brazil (all states and to everywhere) of ‘soybeans’, ‘soybean oil’ and ‘soybean meal’;

# %%
soybeans_oil = comexsta[(comexsta['product'] == 'soybean_oil') & (comexsta['type'] == 'Export') ]

# %%
soybeans_oil['date'] = pd.to_datetime(soybeans_oil['date'])

# %% [markdown]
# ### Análise por Mês

# %% [markdown]
# Preparando os dados - Soja

# %%
soybeans = comexsta[(comexsta['product'] == 'soybeans') & (comexsta['type'] == 'Export')]
soybeans['date'] = pd.to_datetime(soybeans['date'])

meses = {}
z = 0

for j in range(1,13):
    for i in range(1997,2020):
        exec("meses" + str([z]) +" = soybeans[soybeans['date'] =='" + str(i) +"-"+ str('%0.2d' % j) +"-01']['date'].count()")
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,23)
soybeans_jan = {k: meses[k] for k in keys}
soybeans_jan = sum(soybeans_jan.values())

keys = range(23,46)
soybeans_fev = {k: meses[k] for k in keys}
soybeans_fev = sum(soybeans_fev.values())

keys = range(46,69)
soybeans_mar = {k: meses[k] for k in keys}
soybeans_mar = sum(soybeans_mar.values())

keys = range(69,92)
soybeans_abr = {k: meses[k] for k in keys}
soybeans_abr = sum(soybeans_abr.values())

keys = range(92,115)
soybeans_mai = {k: meses[k] for k in keys}
soybeans_mai = sum(soybeans_mai.values())

keys = range(115,138)
soybeans_jun = {k: meses[k] for k in keys}
soybeans_jun = sum(soybeans_jun.values())

keys = range(138,161)
soybeans_jul = {k: meses[k] for k in keys}
soybeans_jul = sum(soybeans_jul.values())


keys = range(161,184)
soybeans_ago = {k: meses[k] for k in keys}
soybeans_ago = sum(soybeans_ago.values())

keys = range(184,207)
soybeans_set = {k: meses[k] for k in keys}
soybeans_set = sum(soybeans_set.values())

keys = range(207,230)
soybeans_out = {k: meses[k] for k in keys}
soybeans_out = sum(soybeans_out.values())

keys = range(230,253)
soybeans_nov = {k: meses[k] for k in keys}
soybeans_nov = sum(soybeans_nov.values())

keys = range(253,276)
soybeans_dez = {k: meses[k] for k in keys}
soybeans_dez = sum(soybeans_dez.values())


soybeans_list = [soybeans_jan,soybeans_fev,soybeans_mar,soybeans_abr,soybeans_mai,soybeans_jun,soybeans_jul,
                 soybeans_ago,soybeans_set,soybeans_out,soybeans_nov,soybeans_dez]

###################################################################################################################

#Óleo de Soja 

soybeans_oil = comexsta[(comexsta['product'] == 'soybean_oil') & (comexsta['type'] == 'Export') ]

soybeans_oil['date'] = pd.to_datetime(soybeans_oil['date'])

meses = {}
z = 0

for j in range(1,13):
    for i in range(1997,2020):
        exec("meses" + str([z]) +" = soybeans_oil[soybeans_oil['date'] =='" + str(i) +"-"+ str('%0.2d' % j) +"-01']['date'].count()")
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,23)
soybeans_oil_jan = {k: meses[k] for k in keys}
soybeans_oil_jan = sum(soybeans_oil_jan.values())

keys = range(23,46)
soybeans_oil_fev = {k: meses[k] for k in keys}
soybeans_oil_fev = sum(soybeans_oil_fev.values())

keys = range(46,69)
soybeans_oil_mar = {k: meses[k] for k in keys}
soybeans_oil_mar = sum(soybeans_oil_mar.values())

keys = range(69,92)
soybeans_oil_abr = {k: meses[k] for k in keys}
soybeans_oil_abr = sum(soybeans_oil_abr.values())

keys = range(92,115)
soybeans_oil_mai = {k: meses[k] for k in keys}
soybeans_oil_mai = sum(soybeans_oil_mai.values())

keys = range(115,138)
soybeans_oil_jun = {k: meses[k] for k in keys}
soybeans_oil_jun = sum(soybeans_oil_jun.values())

keys = range(138,161)
soybeans_oil_jul = {k: meses[k] for k in keys}
soybeans_oil_jul = sum(soybeans_oil_jul.values())


keys = range(161,184)
soybeans_oil_ago = {k: meses[k] for k in keys}
soybeans_oil_ago = sum(soybeans_oil_ago.values())

keys = range(184,207)
soybeans_oil_set = {k: meses[k] for k in keys}
soybeans_oil_set = sum(soybeans_oil_set.values())

keys = range(207,230)
soybeans_oil_out = {k: meses[k] for k in keys}
soybeans_oil_out = sum(soybeans_oil_out.values())

keys = range(230,253)
soybeans_oil_nov = {k: meses[k] for k in keys}
soybeans_oil_nov = sum(soybeans_oil_nov.values())

keys = range(253,276)
soybeans_oil_dez = {k: meses[k] for k in keys}
soybeans_oil_dez = sum(soybeans_oil_dez.values())


soybeans_oil_list = [soybeans_oil_jan,soybeans_oil_fev,soybeans_oil_mar,soybeans_oil_abr,soybeans_oil_mai,soybeans_oil_jun,soybeans_oil_jul,
                 soybeans_oil_ago,soybeans_oil_set,soybeans_oil_out,soybeans_oil_nov,soybeans_oil_dez]


##########################################################################################################################################################

#Farelo de Soja

soybean_meal = comexsta[(comexsta['product'] == 'soybean_meal') & (comexsta['type'] == 'Export') ]
soybean_meal['date'] = pd.to_datetime(soybean_meal['date'])

meses = {}
z = 0

for j in range(1,13):
    for i in range(1997,2020):
        exec("meses" + str([z]) +" = soybean_meal[soybean_meal['date'] =='" + str(i) +"-"+ str('%0.2d' % j) +"-01']['date'].count()")
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,23)
soybean_meal_jan = {k: meses[k] for k in keys}
soybean_meal_jan = sum(soybean_meal_jan.values())

keys = range(23,46)
soybean_meal_fev = {k: meses[k] for k in keys}
soybean_meal_fev = sum(soybean_meal_fev.values())

keys = range(46,69)
soybean_meal_mar = {k: meses[k] for k in keys}
soybean_meal_mar = sum(soybean_meal_mar.values())

keys = range(69,92)
soybean_meal_abr = {k: meses[k] for k in keys}
soybean_meal_abr = sum(soybean_meal_abr.values())

keys = range(92,115)
soybean_meal_mai = {k: meses[k] for k in keys}
soybean_meal_mai = sum(soybean_meal_mai.values())

keys = range(115,138)
soybean_meal_jun = {k: meses[k] for k in keys}
soybean_meal_jun = sum(soybean_meal_jun.values())

keys = range(138,161)
soybean_meal_jul = {k: meses[k] for k in keys}
soybean_meal_jul = sum(soybean_meal_jul.values())


keys = range(161,184)
soybean_meal_ago = {k: meses[k] for k in keys}
soybean_meal_ago = sum(soybean_meal_ago.values())

keys = range(184,207)
soybean_meal_set = {k: meses[k] for k in keys}
soybean_meal_set = sum(soybean_meal_set.values())

keys = range(207,230)
soybean_meal_out = {k: meses[k] for k in keys}
soybean_meal_out = sum(soybean_meal_out.values())

keys = range(230,253)
soybean_meal_nov = {k: meses[k] for k in keys}
soybean_meal_nov = sum(soybean_meal_nov.values())

keys = range(253,276)
soybean_meal_dez = {k: meses[k] for k in keys}
soybean_meal_dez = sum(soybean_meal_dez.values())


soybean_meal_list = [soybean_meal_jan,soybean_meal_fev,soybean_meal_mar,soybean_meal_abr,soybean_meal_mai,soybean_meal_jun,soybean_meal_jul,
                 soybean_meal_ago,soybean_meal_set,soybean_meal_out,soybean_meal_nov,soybean_meal_dez]

#################################################################################################################

# %% [markdown]
# Gráfico

# %% [markdown]
# No gráfico abaixo foi contado e somado a quantidade de exportações mensais para cada um dos anos. Contamos a quantidade de exportações para o mês de janeiro e somamos com todos os anos entre 97 a 2019. Podemos notar um expressivo crescimento das exportações de soja entre os meses de fevereiro a maio. Há também um comportamento parecido de crescimento e baixa para o farelo de soja e o óleo de soja no meio do gráfico.

# %%
Meses = ['Jan','Fev','Mar', 'Abr', 'Mai','Jun','Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']

meses = pd.DataFrame(Meses, columns = ['Meses'])
soybean_df = pd.DataFrame(soybeans_list, columns = ['soybean'])
soybeans_oil_df = pd.DataFrame(soybeans_oil_list, columns = ['soybeans_oil'])
soybean_meal_df = pd.DataFrame(soybean_meal_list, columns = ['soybean_meal'])

result = pd.concat([soybean_df, soybeans_oil_df,soybean_meal_df], axis=1, sort=False)
df = pd.concat([meses, result], axis=1, sort=False)


plt.figure(figsize=(20,10))

plt.plot('Meses','soybean', data=df,marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=3,label="Soja");

plt.plot('Meses','soybeans_oil', data=df,marker='', markerfacecolor='red', markersize=12, color='red', linewidth=3,label="Óleo de Soja");

plt.plot('Meses','soybean_meal', data=df,marker='', markerfacecolor='olive', markersize=12, color='olive', linewidth=3,label="Farelo de Soja");


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('meses', fontsize=20, labelpad=20)
plt.ylabel('Quantidade de exportações', fontsize=20, labelpad=20);

plt.title('Soma total por mês das exportações para Soja, Óleo e Farelo de Soja entre 97 e 2019', size=20, pad=15)

plt.xticks(rotation=45);

plt.legend(fontsize=20)

plt.show()

# %% [markdown]
# ### Análise anual

# %% [markdown]
# Preparando os dados

# %%
#Soja

soybean = comexsta[(comexsta['product'] == 'soybeans') & (comexsta['type'] == 'Export')]
soybean['date'] = pd.to_datetime(soybean['date'])

meses = {}
z = 0

for j in range(1997,2020):
    for i in range(1,13):
        exec("meses" + str([z]) +" = soybean[soybean['date'] =='" + str(j) +"-"+ str('%0.2d' % i) +"-01']['date'].count()")
        #print(j)
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,12)
soybean_97 = {k: meses[k] for k in keys}
soybean_97 = sum(soybean_97.values())

keys = range(12,24)
soybean_98 = {k: meses[k] for k in keys}
soybean_98 = sum(soybean_98.values())

keys = range(24,36)
soybean_99 = {k: meses[k] for k in keys}
soybean_99 = sum(soybean_99.values())

keys = range(36,48)
soybean_00 = {k: meses[k] for k in keys}
soybean_00 = sum(soybean_00.values())

keys = range(48,60)
soybean_01 = {k: meses[k] for k in keys}
soybean_01 = sum(soybean_01.values())

keys = range(60,72)
soybean_02 = {k: meses[k] for k in keys}
soybean_02 = sum(soybean_02.values())

keys = range(72,84)
soybean_03 = {k: meses[k] for k in keys}
soybean_03 = sum(soybean_03.values())


keys = range(84,96)
soybean_04 = {k: meses[k] for k in keys}
soybean_04 = sum(soybean_04.values())

keys = range(96,108)
soybean_05 = {k: meses[k] for k in keys}
soybean_05 = sum(soybean_05.values())

keys = range(108,120)
soybean_06 = {k: meses[k] for k in keys}
soybean_06  = sum(soybean_06 .values())

keys = range(120,132)
soybean_07  = {k: meses[k] for k in keys}
soybean_07 = sum(soybean_07.values())

keys = range(132,144)
soybean_08 = {k: meses[k] for k in keys}
soybean_08 = sum(soybean_08.values())

keys = range(144,156)
soybean_09 = {k: meses[k] for k in keys}
soybean_09 = sum(soybean_09.values())

keys = range(156,168)
soybean_10 = {k: meses[k] for k in keys}
soybean_10 = sum(soybean_10.values())

keys = range(168,180)
soybean_11 = {k: meses[k] for k in keys}
soybean_11 = sum(soybean_11.values())

keys = range(180,192)
soybean_12 = {k: meses[k] for k in keys}
soybean_12 = sum(soybean_12.values())

keys = range(192,204)
soybean_13 = {k: meses[k] for k in keys}
soybean_13 = sum(soybean_13.values())

keys = range(204,216)
soybean_14 = {k: meses[k] for k in keys}
soybean_14 = sum(soybean_14.values())

keys = range(216,228)
soybean_15 = {k: meses[k] for k in keys}
soybean_15 = sum(soybean_15.values())

keys = range(228,240)
soybean_16 = {k: meses[k] for k in keys}
soybean_16 = sum(soybean_16.values())

keys = range(240,252)
soybean_17 = {k: meses[k] for k in keys}
soybean_17 = sum(soybean_17.values())

keys = range(252,264)
soybean_18 = {k: meses[k] for k in keys}
soybean_18 = sum(soybean_18.values())

keys = range(264,276)
soybean_19 = {k: meses[k] for k in keys}
soybean_19 = sum(soybean_19.values())



soybean_list = [soybean_97,soybean_98,soybean_99,soybean_00,soybean_01,soybean_02,soybean_03,
                 soybean_04,soybean_05,soybean_06,soybean_07,soybean_08,soybean_09,soybean_10,
                 soybean_11,soybean_12,soybean_13,soybean_14,soybean_15,soybean_16,soybean_17,
                 soybean_18,soybean_19]

# %% [markdown]
# Óleo de Soja

# %%
soybean_oil = comexsta[(comexsta['product'] == 'soybean_oil') & (comexsta['type'] == 'Export')]
soybean_oil['date'] = pd.to_datetime(soybean_oil['date'])

meses = {}
z = 0

for j in range(1997,2020):
    for i in range(1,13):
        exec("meses" + str([z]) +" = soybean_oil[soybean_oil['date'] =='" + str(j) +"-"+ str('%0.2d' % i) +"-01']['date'].count()")
        #print(j)
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,12)
soybean_oil_97 = {k: meses[k] for k in keys}
soybean_oil_97 = sum(soybean_oil_97.values())

keys = range(12,24)
soybean_oil_98 = {k: meses[k] for k in keys}
soybean_oil_98 = sum(soybean_oil_98.values())

keys = range(24,36)
soybean_oil_99 = {k: meses[k] for k in keys}
soybean_oil_99 = sum(soybean_oil_99.values())

keys = range(36,48)
soybean_oil_00 = {k: meses[k] for k in keys}
soybean_oil_00 = sum(soybean_oil_00.values())

keys = range(48,60)
soybean_oil_01 = {k: meses[k] for k in keys}
soybean_oil_01 = sum(soybean_oil_01.values())

keys = range(60,72)
soybean_oil_02 = {k: meses[k] for k in keys}
soybean_oil_02 = sum(soybean_oil_02.values())

keys = range(72,84)
soybean_oil_03 = {k: meses[k] for k in keys}
soybean_oil_03 = sum(soybean_oil_03.values())


keys = range(84,96)
soybean_oil_04 = {k: meses[k] for k in keys}
soybean_oil_04 = sum(soybean_oil_04.values())

keys = range(96,108)
soybean_oil_05 = {k: meses[k] for k in keys}
soybean_oil_05 = sum(soybean_oil_05.values())

keys = range(108,120)
soybean_oil_06 = {k: meses[k] for k in keys}
soybean_oil_06  = sum(soybean_oil_06 .values())

keys = range(120,132)
soybean_oil_07  = {k: meses[k] for k in keys}
soybean_oil_07 = sum(soybean_oil_07.values())

keys = range(132,144)
soybean_oil_08 = {k: meses[k] for k in keys}
soybean_oil_08 = sum(soybean_oil_08.values())

keys = range(144,156)
soybean_oil_09 = {k: meses[k] for k in keys}
soybean_oil_09 = sum(soybean_oil_09.values())

keys = range(156,168)
soybean_oil_10 = {k: meses[k] for k in keys}
soybean_oil_10 = sum(soybean_oil_10.values())

keys = range(168,180)
soybean_oil_11 = {k: meses[k] for k in keys}
soybean_oil_11 = sum(soybean_oil_11.values())

keys = range(180,192)
soybean_oil_12 = {k: meses[k] for k in keys}
soybean_oil_12 = sum(soybean_oil_12.values())

keys = range(192,204)
soybean_oil_13 = {k: meses[k] for k in keys}
soybean_oil_13 = sum(soybean_oil_13.values())

keys = range(204,216)
soybean_oil_14 = {k: meses[k] for k in keys}
soybean_oil_14 = sum(soybean_oil_14.values())

keys = range(216,228)
soybean_oil_15 = {k: meses[k] for k in keys}
soybean_oil_15 = sum(soybean_oil_15.values())

keys = range(228,240)
soybean_oil_16 = {k: meses[k] for k in keys}
soybean_oil_16 = sum(soybean_oil_16.values())

keys = range(240,252)
soybean_oil_17 = {k: meses[k] for k in keys}
soybean_oil_17 = sum(soybean_oil_17.values())

keys = range(252,264)
soybean_oil_18 = {k: meses[k] for k in keys}
soybean_oil_18 = sum(soybean_oil_18.values())

keys = range(264,276)
soybean_oil_19 = {k: meses[k] for k in keys}
soybean_oil_19 = sum(soybean_oil_19.values())



soybean_oil_list = [soybean_oil_97,soybean_oil_98,soybean_oil_99,soybean_oil_00,soybean_oil_01,soybean_oil_02,soybean_oil_03,
                 soybean_oil_04,soybean_oil_05,soybean_oil_06,soybean_oil_07,soybean_oil_08,soybean_oil_09,soybean_oil_10,
                 soybean_oil_11,soybean_oil_12,soybean_oil_13,soybean_oil_14,soybean_oil_15,soybean_oil_16,soybean_oil_17,
                 soybean_oil_18,soybean_oil_19]

# %% [markdown]
# Farelo de Soja

# %%
soybean_meal = comexsta[(comexsta['product'] == 'soybean_meal') & (comexsta['type'] == 'Export')]
soybean_meal['date'] = pd.to_datetime(soybean_meal['date'])

meses = {}
z = 0

for j in range(1997,2020):
    for i in range(1,13):
        exec("meses" + str([z]) +" = soybean_meal[soybean_meal['date'] =='" + str(j) +"-"+ str('%0.2d' % i) +"-01']['date'].count()")
        #print(j)
        z += 1

# for k in range(1,2):      
#     exec("meses_" + str(k)+" = sum(meses.values())")
        
      
keys = range(0,12)
soybean_meal_97 = {k: meses[k] for k in keys}
soybean_meal_97 = sum(soybean_meal_97.values())

keys = range(12,24)
soybean_meal_98 = {k: meses[k] for k in keys}
soybean_meal_98 = sum(soybean_meal_98.values())

keys = range(24,36)
soybean_meal_99 = {k: meses[k] for k in keys}
soybean_meal_99 = sum(soybean_meal_99.values())

keys = range(36,48)
soybean_meal_00 = {k: meses[k] for k in keys}
soybean_meal_00 = sum(soybean_meal_00.values())

keys = range(48,60)
soybean_meal_01 = {k: meses[k] for k in keys}
soybean_meal_01 = sum(soybean_meal_01.values())

keys = range(60,72)
soybean_meal_02 = {k: meses[k] for k in keys}
soybean_meal_02 = sum(soybean_meal_02.values())

keys = range(72,84)
soybean_meal_03 = {k: meses[k] for k in keys}
soybean_meal_03 = sum(soybean_meal_03.values())


keys = range(84,96)
soybean_meal_04 = {k: meses[k] for k in keys}
soybean_meal_04 = sum(soybean_meal_04.values())

keys = range(96,108)
soybean_meal_05 = {k: meses[k] for k in keys}
soybean_meal_05 = sum(soybean_meal_05.values())

keys = range(108,120)
soybean_meal_06 = {k: meses[k] for k in keys}
soybean_meal_06  = sum(soybean_meal_06 .values())

keys = range(120,132)
soybean_meal_07  = {k: meses[k] for k in keys}
soybean_meal_07 = sum(soybean_meal_07.values())

keys = range(132,144)
soybean_meal_08 = {k: meses[k] for k in keys}
soybean_meal_08 = sum(soybean_meal_08.values())

keys = range(144,156)
soybean_meal_09 = {k: meses[k] for k in keys}
soybean_meal_09 = sum(soybean_meal_09.values())

keys = range(156,168)
soybean_meal_10 = {k: meses[k] for k in keys}
soybean_meal_10 = sum(soybean_meal_10.values())

keys = range(168,180)
soybean_meal_11 = {k: meses[k] for k in keys}
soybean_meal_11 = sum(soybean_meal_11.values())

keys = range(180,192)
soybean_meal_12 = {k: meses[k] for k in keys}
soybean_meal_12 = sum(soybean_meal_12.values())

keys = range(192,204)
soybean_meal_13 = {k: meses[k] for k in keys}
soybean_meal_13 = sum(soybean_meal_13.values())

keys = range(204,216)
soybean_meal_14 = {k: meses[k] for k in keys}
soybean_meal_14 = sum(soybean_meal_14.values())

keys = range(216,228)
soybean_meal_15 = {k: meses[k] for k in keys}
soybean_meal_15 = sum(soybean_meal_15.values())

keys = range(228,240)
soybean_meal_16 = {k: meses[k] for k in keys}
soybean_meal_16 = sum(soybean_meal_16.values())

keys = range(240,252)
soybean_meal_17 = {k: meses[k] for k in keys}
soybean_meal_17 = sum(soybean_meal_17.values())

keys = range(252,264)
soybean_meal_18 = {k: meses[k] for k in keys}
soybean_meal_18 = sum(soybean_meal_18.values())

keys = range(264,276)
soybean_meal_19 = {k: meses[k] for k in keys}
soybean_meal_19 = sum(soybean_meal_19.values())



soybean_meal_list = [soybean_meal_97,soybean_meal_98,soybean_meal_99,soybean_meal_00,soybean_meal_01,soybean_meal_02,soybean_meal_03,
                 soybean_meal_04,soybean_meal_05,soybean_meal_06,soybean_meal_07,soybean_meal_08,soybean_meal_09,soybean_meal_10,
                 soybean_meal_11,soybean_meal_12,soybean_meal_13,soybean_meal_14,soybean_meal_15,soybean_meal_16,soybean_meal_17,
                 soybean_meal_18,soybean_meal_19]

# %% [markdown]
# No gráfico abaixo temos o total de exportações por ano. Podemos notar uma tendência de crescimento das exportações ao longo dos anos com um crescente aumento das exportações de óleo de soja entre 2017 a 2019 equiparando-se com a soja.

# %%
Anos = ['1997','1998','1999', '2000', '2001','2002','2003', '2004', '2005', '2006', '2007', '2008','2009','2010','2011',
       '2012','2013','2014','2015','2016','2017','2018','2019']

anos = pd.DataFrame(Anos, columns = ['Anos'])
soybean_df = pd.DataFrame(soybean_list, columns = ['soybean'])
soybeans_oil_df = pd.DataFrame(soybean_oil_list, columns = ['soybeans_oil'])
soybean_meal_df = pd.DataFrame(soybean_meal_list, columns = ['soybean_meal'])

result = pd.concat([soybean_df, soybeans_oil_df,soybean_meal_df], axis=1, sort=False)
df = pd.concat([anos, result], axis=1, sort=False)


plt.figure(figsize=(20,10))

plt.plot('Anos','soybean', data=df,marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=3,label="Soja");

plt.plot('Anos','soybeans_oil', data=df,marker='', markerfacecolor='red', markersize=12, color='red', linewidth=3,label="Óleo de Soja");

plt.plot('Anos','soybean_meal', data=df,marker='', markerfacecolor='olive', markersize=12, color='olive', linewidth=3,label="Farelo de Soja");


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Anos', fontsize=20, labelpad=20)
plt.ylabel('Quantidade de exportações', fontsize=20, labelpad=20);

plt.title('Quantidade de Exportações por mês', size=20, pad=15)



#plt.yticks([0, 500, 1000, 1500, 2000, 2500, 3000, 3500], 
#           ['0', '500 milhões', '1 bilhão', '1,5 bilhões', '2 bilhões', '2,5 bilhões', '3 bilhões', '3,5 bilhões'],
#           fontsize=18);



#plt.xticks(['2016-12-31', '2017-12-31',
#            '2018-12-31', '2019-12-31'], 
           
#          ['2016', '2017', '2018', '2019'], fontsize=18)


plt.xticks(rotation=45);


plt.legend(fontsize=20)

plt.show()

# %% [markdown]
# ## 2. What are the 3 most important products exported by Brazil in the last 5 years?

# %% [markdown]
# No gráfico abaixo, o primeiro, pegamos o valor das exportações em dólares para cada um dos produtos. Enquanto no segundo gráfico pegamos a quantidade em toneladas exportada.  Podemos notar que os três maiores produtos possuem a mesma proporção em valores (Dólares) e valores em toneladas. Em razão disso, podemos dizer que soja, Farelo de Soja e Milho são os três principais produtos exportados pelo Brasil nos últimos 5 anos.

# %%
#Dados

produtos = comexsta[(comexsta['type'] == 'Export')]
produtos['date'] = pd.to_datetime(produtos['date'])
produtos = produtos.rename(columns={"usd": "Dólar Americano", "tons": "Toneladas", "product":"Produtos"})

ultimos_5_anos = produtos.query(' "2015-01-01" < date <= "2020-12-01"')

ultimos_5_anos['Produtos'] = ultimos_5_anos['Produtos'].replace({'corn': 'Milho', 'soybean_meal':'Refeição a base de Soja',
                                                              'soybean_oil':'Óleo de Soja', 'soybeans':'Soja',
                                                              'sugar':'Açucar','wheat':'Trigo'})

# %%
#Gráfico



ultimos_5_anos.groupby('Produtos')['Dólar Americano'].mean().plot.bar(rot=0, subplots=False,figsize=(20, 10))
 


plt.title('Valores médios em Dólares para cada produto nos últimos 5 anos', size=20, pad=15)

plt.yticks([0, 5e06, 10e06, 15e06, 20e06], 
          ['R$ 0', 'R$ 5 milhões', 'R$ 10 milhões', 'R$ 15 milhões', 'R$ 20 milhões'],
          fontsize=18);




plt.ylabel('',fontsize=20)


plt.xticks(rotation=45,fontsize=20);

# %%
axes2 = ultimos_5_anos.groupby('Produtos')['Toneladas'].mean().plot.bar(rot=0, subplots=False,figsize=(20, 10))
                                                                                
plt.title('Valores médios em Toneladas para cada produto nos últimos 5 anos', size=20, pad=15)

plt.yticks([0, 10e03, 20e03, 30e03, 40e03, 50e03], 
          ['R$ 0', 'R$ 10 mil', 'R$ 20 mil', 'R$ 30 mil', 'R$ 40 mil', 'R$ 50 mil'],
          fontsize=18);

plt.ylabel('',fontsize=20)


plt.xticks(rotation=45,fontsize=20);

# %% [markdown]
# Os valores em dólares de Soja possuem a maior fatia em relação aos outros produtos, ou seja, mais da metade dos produtos exportados.

# %%
# Gráfico de pizza (donnut) da soma da idenização por região 

# definindo o tamanho do gráfico
fig,ax = plt.subplots(figsize=(11, 9)) 

# dados para plotar
i1 = ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum().sort_values(ascending=False)[0]
i2 = ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum().sort_values(ascending=False)[1]
i3 = ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum().sort_values(ascending=False)[2]
i4 = ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum().sort_values(ascending=False)[3]
i5 = ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum().sort_values(ascending=False)[4] + ultimos_5_anos.groupby('Produtos')['Dólar Americano'].sum()[5]



colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'red']
size = [i1,i2,i3,i4,i5]
labels = ['Soja','Açucar','Farelo de Soja','Milho','Óleo de Soja e Trigo']

# Plot
plt.title('Share dos valores em Dólares para cada produto nos últimos 5 anos ', size=20, pad=15)
patches, texts, autotexts = ax.pie(size, colors=colors, autopct='%1.1f%%', startangle=230)

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

for x in autotexts:
  x.set_fontsize(13.5)

for x in texts:
  x.set_fontsize(13.5)

ax.legend(patches, labels,
          loc='upper right',
          fontsize=14,
          bbox_to_anchor=(0.5, 0, 0.7, 1))

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# para ignorar avisos

import warnings
warnings.filterwarnings('ignore');

# %% [markdown]
# ## 3. What are the main routes through which Brazil have been exporting ‘corn’ in the last few years? Are there differences in the relative importancem of routes depending on the product?

# %% [markdown]
# Dados

# %%
rotas_corn = comexsta[(comexsta['product'] == 'corn') & (comexsta['type'] == 'Export')].query(' "2015-01-01" < date <= "2020-12-01"')
rotas = comexsta[(comexsta['type'] == 'Export')].query(' "2015-01-01" < date <= "2020-12-01"')

# %% [markdown]
# Podemos observar que em relação a quantidade de exportações de milho a rota por oceano se mostra a mais importante em relação as outras rotas. Cerca de 78% da quantidade de exportações de milho são feitas através do mar.

# %%
#
fig,ax = plt.subplots(figsize=(11, 9)) 


i1 = rotas_corn.groupby('route')['product'].count().sort_values(ascending=False)[0]
i2 = rotas_corn.groupby('route')['product'].count().sort_values(ascending=False)[1]
i3 = rotas_corn.groupby('route')['product'].count().sort_values(ascending=False)[2]
i4 = rotas_corn.groupby('route')['product'].count().sort_values(ascending=False)[3]
i5 = rotas_corn.groupby('route')['product'].count().sort_values(ascending=False)[4]



colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'red']
size = [i1,i2,i3,i4,i5]
labels = ['Mar','Rio','Terra','Outros','Ar']


plt.title('Share das principais rotas pelas quais o Basil exportou milho no últimos 5 anos ', size=20, pad=15)
patches, texts, autotexts = ax.pie(size, colors=colors, autopct='%1.1f%%', startangle=230)


centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

for x in autotexts:
  x.set_fontsize(13.5)

for x in texts:
  x.set_fontsize(13.5)

ax.legend(patches, labels,
          loc='upper right',
          fontsize=14,
          bbox_to_anchor=(0.5, 0, 0.7, 1))

plt.axis('equal')



import warnings
warnings.filterwarnings('ignore');

# %% [markdown]
# Em relação a valores em dolares as exportações de milho arrecadam cerca de 22 bilhôes de doláres feita por oceano.

# %%
fig,ax = plt.subplots(figsize=(15, 8)) 


rotas_corn.groupby('route')['usd'].sum().sort_values(ascending=False).plot.bar()



plt.title('Principais Rotas de exportação de Milho nos últimos 5 anos (Em dólares)', size=20, pad=15)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores de exportações (dolares)', fontsize=20, labelpad=20);

plt.yticks([0, 50000e05, 100000e05, 150000e05, 200000e05, 250000e05], 
          ['0', '5 bilhões', '10 bilhões', '15 bilhões', '20 bilhões', '25 bilhões'],
          fontsize=18);

plt.xticks(rotation=45);

# %%
fig,ax = plt.subplots(figsize=(15, 8)) 


rotas_corn.groupby('route')['tons'].sum().sort_values(ascending=False).plot.bar()



plt.title('Principais Rotas de exportação de Milho nos últimos 5 anos (toneladas)', size=20, pad=15)

a
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Quantidade de exportações (toneladas)', fontsize=20, labelpad=20);

plt.yticks([0, 0.2e08, 0.4e08, 0.6e08, 0.8e08, 1e08, 1.2e08, 1.4e08], 
          ['0', '20 milhões', ' 40 milhões', '60 bilhões', '80 bilhões', '100 bilhões', '120 bilhões', '140 bilhões'],
          fontsize=18);

plt.xticks(rotation=45);

# %% [markdown]
# Os gráficos de Radar, apresentados na célula abaixo, mostram a quantidade de exportações por produto e por rota (Os valores são apresentados em porcentagem). Podemos observamos que todos os produtos, possuem na sua maior parte, rotas através do mar. É possível notar que o produto óleo de Soja possuem uma parcela considerável de exportações através de outras rotas.
#
# Em geral, não há diferença de rotas em relação aos produtos.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 

df = pd.DataFrame({
'Prod. ':  ['Açucar','Milho','Soja','Farelo de Soja', 'Óleo de Soja', 'Trigo'],
    
'Mar':    [74.03, 78.74,  88.40,  97.41,  43.31,  62.71],
'Terra':  [6.77,  6.28,   2.00,   1.31,   20.73,  13.28],
'Outros': [18.46, 6.06,   2.46,   0.69,   35.23,  18.93],
'Ar':     [0.58,  5.09,   1.82,   0.57,    0.49,  5.08],
'Lago':   [0.16,  3.84,   5.33,   0.02,    0.24,     0]
})

 

 
def make_spider(row, title, color):
 
    
    categories=list(df)[1:]
    N = len(categories)

    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    
    ax = plt.subplot(3,3,row+1, polar=True, )

    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    
    ax.set_rlabel_position(0)
    plt.yticks([10,20,30,40,50,60,70,80], ["10","20","30","40","50","60","70","80"], color="grey", size=7)
    #plt.ylim(0,70)

    
    values=df.loc[row].drop('Prod. ').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    
    plt.title(title, size=11, color=color, y=1.1)
 


my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 

my_palette = plt.cm.get_cmap("Set2", len(df.index))
 

for row in range(0, len(df.index)):
    make_spider( row=row, title='Prod. '+df['Prod. '][row], color=my_palette(row))

# %% [markdown]
# ## 4. Which countries have been the most important trade partners for Brazil in terms of ‘corn’ and ‘sugar’ in the last 3 years?

# %% [markdown]
# Dados

# %%
trade = comexsta[(comexsta['product'] == 'sugar') | (comexsta['product'] == 'corn')].query(' "2017-01-01" <= date <= "2020-12-01"')

# %% [markdown]
# Listamos no gráfico abaixo os 10 principais países no qual o Brasil exportou açucar e milho nos últimos 3 anos.

# %%
fig,ax = plt.subplots(figsize=(20, 10)) 


trade.groupby('country')['usd'].sum().sort_values(ascending=False).plot.bar()



plt.title('Principais parceiros comerciais do Brasil em termos dos produtos Milho e Açucar nos últimos 3 anos (Top 10)', size=20, pad=15)



ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);
plt.xlim(-0.3,9.5)

plt.yticks([0, 5e08, 10e08, 15e08, 20e08, 25e08, 30e08, 35e08], 
          ['0', '5 bilhões', '10 bilhões', '15 bilhões', '20 bilhões', '25 bilhões', '30 bilhões',
           '35 bilhões'],
          fontsize=18);

plt.xticks(rotation=45);

# %% [markdown]
# ## 5. For each of the products in the dataset, show the 5 most important states in terms of exports?

# %% [markdown]
# Preparando Dados

# %%
df = comexsta[(comexsta['type'] == 'Export')]

df = df.replace({'corn': 'Milho','wheat': 'Trigo','sugar':'Açucar','soybeans':'Soja','soybean_meal':'Farelo de Soja','soybean_oil':'Óleo de Soja'})

df1 = df[(df['product'] == 'Milho')].sort_values(by=['usd'],ascending=False)

df1 = df[(df['product'] == 'Milho')].sort_values(by=['usd'],ascending=False)
         
export1 = pd.pivot_table(df1,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export1.T.sort_values(by=['Milho'],ascending=False)
export1 = export1.T.sort_values(by=['Milho'],ascending=False)
export1 = export1.iloc[0:5]

df2 = df[(df['product'] == 'Farelo de Soja')].sort_values(by=['usd'],ascending=False)
         
export2 = pd.pivot_table(df2,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export2.T.sort_values(by=['Farelo de Soja'],ascending=False)
export2 = export2.T.sort_values(by=['Farelo de Soja'],ascending=False)
export2 = export2.iloc[0:5]


df3 = df[(df['product'] == 'Óleo de Soja')].sort_values(by=['usd'],ascending=False)
         
export3 = pd.pivot_table(df3,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export3.T.sort_values(by=['Óleo de Soja'],ascending=False)
export3 = export3.T.sort_values(by=['Óleo de Soja'],ascending=False)
export3 = export3.iloc[0:5]

df4 = df[(df['product'] == 'Soja')].sort_values(by=['usd'],ascending=False)
         
export4 = pd.pivot_table(df4,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export4.T.sort_values(by=['Soja'],ascending=False)
export4 = export4.T.sort_values(by=['Soja'],ascending=False)
export4 = export4.iloc[0:5]

df5 = df[(df['product'] == 'Açucar')].sort_values(by=['usd'],ascending=False)
         
export5 = pd.pivot_table(df5,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export5.T.sort_values(by=['Açucar'],ascending=False)
export5 = export5.T.sort_values(by=['Açucar'],ascending=False)
export5 = export5.iloc[0:5]

df6 = df[(df['product'] == 'Trigo')].sort_values(by=['usd'],ascending=False)
         
export6 = pd.pivot_table(df6,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export6.T.sort_values(by=['Trigo'],ascending=False)
export6 = export6.T.sort_values(by=['Trigo'],ascending=False)
export6 = export6.iloc[0:5]

# %%
export1.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Milho', size=20, pad=15)

plt.yticks([0, 1e06, 2e06, 3e06, 4e06, 5e06, 6e06, 7e06], 
          ['0', '1 milhões', '2 milhões', '3 milhões', '4 milhões', '5 milhões', '6 milhões',
           '7 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
ax = export2.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Farelo de Soja', size=20, pad=15)

plt.yticks([0, 0.2e07, 0.4e07, 0.6e07, 0.8e07, 1e07], 
          ['0', '2 milhões', '4 milhões', '6 milhões', '8 milhões', '10 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
ax = export3.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Óleo de Soja', size=20, pad=15)

plt.yticks([0, 1e06, 2e06, 3e06, 4e06, 5e06], 
          ['0', '1 milhões', '2 milhões', '3 milhões', '4 milhões', '5 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
ax = export4.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Soja', size=20, pad=15)

plt.yticks([0, 0.5e07, 1e07, 1.5e07, 2.0e07, 2.5e07, 3.0e07, 3.5e07], 
          ['0', '5 milhões', '10 milhões', '15 milhões', '20 milhões', '25 milhões', '30 milhões', '35 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
ax = export5.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Açucar', size=20, pad=15)

plt.yticks([0, 1e06, 2e06, 3e06, 4e06, 5e06], 
          ['0', '1 milhões', '2 milhões', '3 milhões', '4 milhões', '5 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
ax = export6.T.plot.bar(rot=0,figsize=(20, 10),stacked=False)

plt.title('5 estados mais importantes em termos de exportação de Trigo', size=20, pad=15)

plt.yticks([0, 1e06, 2e06, 3e06, 4e06, 5e06, 6e06, 7e06, 8e06], 
          ['0', '1 milhões', '2 milhões', '3 milhões', '4 milhões', '5 milhões', '6 milhões', '7 milhões', '8 milhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);

plt.legend(fontsize=20);

# %%
    
export = pd.pivot_table(df,values='usd',index=["product"],columns=['state'],fill_value=0).fillna(0).astype(int)
export = export.iloc[:,0:27]

ax = export.plot.bar(rot=0,figsize=(20, 10),stacked=True)

plt.title('Todos os estados em termos de exportação de Açucar, Farelo de Soja, Milho, Soja, Trigo e Óleo de Soja', size=20, pad=15)

plt.yticks([0, 0.25e08, 0.5e08, 0.75e08, 1e08, 1.25e08, 1.5e08, 1.75e08], 
          ['0', '25 milhões', '50 milhões', '75 milhões', '100 milhões', '125 milhões', '150 milhões',
           '175 bilhões'],
          fontsize=18);

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('', fontsize=20, labelpad=20)
plt.ylabel('Valores em dolares ($)', fontsize=20, labelpad=20);
# plt.xlim(-0.3,9.5)

plt.legend(loc="upper left",fontsize=20, ncol=5);

# %% [markdown]
# ## 6. Now, we ask you to show your modelling skills. Feel free to use any type of modelling approach, but bear in mind that the modelling approach depends on the nature of your data, and so different models yield different estimates and forecasts. To help you out in this task we also provide you with a dataset of possible covariates (.xlsx). They all come from public sources (IMF, World Bank) and are presented in index number format. Question: What should be the total brazilian soybeans, soybean_meal, and corn export forecasts, in tons, for the next 11 years (2020-2030)? We’re mostly interested in the annual forecast.

# %% [markdown]
# Colhetando os dados

# %%
covariates = pd.read_excel('covariates.xlsx', sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True)
comexsta = pd.read_csv('data_comexstat.csv', sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding='latin-1', dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
forecast = comexsta[(comexsta['product'] == 'corn') | (comexsta['product'] == 'soybeans') | (comexsta['product'] == ' soybean_meal') | (comexsta['type'] == 'Export') ]
forecast = forecast[(comexsta['type'] == 'Export')]

# %%
forecast.head()
# Out:
#           date product state        country    type   route        tons  \
# 2   1997-01-01    corn    GO        Bolivia  Export  Ground       0.200
# 3   1997-01-01    corn    GO  United States  Export     Sea       3.488
# 5   1997-01-01    corn    MS       Paraguay  Export  Ground      40.000
# 9   1997-01-01    corn    PR    Netherlands  Export     Sea  170000.000
# 10  1997-01-01    corn    PR       Paraguay  Export  Ground     258.300
#
#            usd
# 2        180.0
# 3       5688.0
# 5      38700.0
# 9   20000000.0
# 10    386733.0

# %% [markdown]
# Colhetando variáveis

# %%
forecast_t = forecast[['date','usd','tons',]]
forecast_t
# Out:
#               date         usd        tons
# 2       1997-01-01       180.0       0.200
# 3       1997-01-01      5688.0       3.488
# 5       1997-01-01     38700.0      40.000
# 9       1997-01-01  20000000.0  170000.000
# 10      1997-01-01    386733.0     258.300
# ...            ...         ...         ...
# 117952  2019-12-01       400.0       0.400
# 117957  2019-12-01   6963002.0   36698.000
# 117961  2019-12-01       477.0       0.500
# 117963  2019-12-01        50.0       0.025
# 117964  2019-12-01        85.0       0.010
#
# [105861 rows x 3 columns]

# %%
forecast_t['date'] = pd.to_datetime(forecast_t['date'])
forecast_t.set_index('date', inplace=True)
forecast_anual = forecast_t.resample('Y').sum()

# %%
forecast_t = forecast[['date','usd','tons',]]
forecast_t['date'] = pd.to_datetime(forecast_t['date'])
forecast_t.set_index('date', inplace=True)
forecast_anual = forecast_t.resample('Y').sum()
forecast_anual = forecast_anual.reset_index()
forecast_anual['year'] = forecast_anual['date'].dt.year
forecast_anual['usd'] = forecast_anual['usd'].astype('int64')
forecast_anual['tons'] = forecast_anual['tons'].astype('int64')
#forecast_anual = forecast_anual.drop(columns=['date'])
forecast_anual = forecast_anual.set_index('year')

# %% [markdown]
# Principais parceiros do Brasil exportações de milho, soja e farelo de soja em toneladas

# %%
trade = comexsta[(comexsta['product'] == 'soybeans') | (comexsta['product'] == 'corn') | (comexsta['product'] == 'soybean_meal') ].query(' "2017-01-01" <= date <= "2020-12-01"')
trade.groupby('country')['tons'].sum().sort_values(ascending=False).plot.bar()
plt.xlim(-0.3,9.5);

# %% [markdown]
# Fazendo uma aquisição dos valores do PIB brasileiro em dolares. Dados coletados no The world Bank

# %% [markdown]
# Pib do Brasil

# %%
pib = pd.read_excel('pib.xlsx')
pib = pib.T
pib = pib.reset_index()
pib = pib.rename(columns={'index': 'date',0: 'PIB_Brasil'})
pib_ = pib[['date','PIB_Brasil']]

pib_['date'] = pd.to_datetime(pib_['date'] ,format='%Y')
pib_['year'] = pib_['date'].dt.year
pib_ = pib_.drop(columns=['date'])
pib_ = pib_.set_index('year')

# %% [markdown]
# Pib da China

# %%
pib_China = pd.read_excel('pib_China.xlsx')
pib_China = pib_China.T
pib_China = pib_China.reset_index()
pib_China = pib_China.rename(columns={'index': 'date',0: 'PIB_China'})
pib_China_ = pib_China[['date','PIB_China']]

pib_China_['date'] = pd.to_datetime(pib_China_['date'] ,format='%Y')
pib_China_['year'] = pib_China_['date'].dt.year
pib_China_ = pib_China_.drop(columns=['date'])
pib_China_ = pib_China_.set_index('year')

# %% [markdown]
# PIB da Espanhâ

# %%
pib_Espanha = pd.read_excel('pib_Espanha.xlsx')
pib_Espanha = pib_Espanha.T
pib_Espanha = pib_Espanha.reset_index()
pib_Espanha = pib_Espanha.rename(columns={'index': 'date',0: 'PIB_Espanha'})
pib_Espanha_ = pib_Espanha[['date','PIB_Espanha']]

pib_Espanha_['date'] = pd.to_datetime(pib_Espanha_['date'] ,format='%Y')
pib_Espanha_['year'] = pib_Espanha_['date'].dt.year
pib_Espanha_ = pib_Espanha_.drop(columns=['date'])
pib_Espanha_ = pib_Espanha_.set_index('year')

# %% [markdown]
# PIB da Holanda

# %%
pib_Holanda = pd.read_excel('pib_Holanda.xlsx')
pib_Holanda = pib_Holanda.T
pib_Holanda = pib_Holanda.reset_index()
pib_Holanda = pib_Holanda.rename(columns={'index': 'date',0: 'PIB_Holanda'})
pib_Holanda_ = pib_Holanda[['date','PIB_Holanda']]

pib_Holanda_['date'] = pd.to_datetime(pib_Holanda_['date'] ,format='%Y')
pib_Holanda_['year'] = pib_Holanda_['date'].dt.year
pib_Holanda_ = pib_Holanda_.drop(columns=['date'])
pib_Holanda_ = pib_Holanda_.set_index('year')

# %% [markdown]
# PIN do Iran

# %%
pib_Iran = pd.read_excel('pib_Iran.xlsx')
pib_Iran = pib_Iran.T
pib_Iran = pib_Iran.reset_index()
pib_Iran = pib_Iran.rename(columns={'index': 'date',0: 'PIB_Iran'})
pib_Iran_ = pib_Iran[['date','PIB_Iran']]

pib_Iran_['date'] = pd.to_datetime(pib_Iran_['date'] ,format='%Y')
pib_Iran_['year'] = pib_Iran_['date'].dt.year
pib_Iran_ = pib_Iran_.drop(columns=['date'])
pib_Iran_ = pib_Iran_.set_index('year')

pib_Iran_ = pib_Iran_.fillna(pib_Iran_.median())

# %% [markdown]
# Preço da Soja por Toneladas

# %%
preco_soja = pd.read_excel('preco_soja.xls', names = ['date','preco_soja'])
preco_soja['date'] = pd.to_datetime(preco_soja['date'])
preco_soja.set_index('date', inplace=True)
preco_soja = preco_soja.resample('Y').sum()
preco_soja = preco_soja.reset_index()
preco_soja['year'] = preco_soja['date'].dt.year
preco_soja = preco_soja.drop(columns=['date'])
preco_soja = preco_soja.set_index('year')

# %% [markdown]
# Preço do Farelo de Soja

# %%
preco_farelo_soja = pd.read_excel('preco_farelo_soja.xls', names = ['date','preco_farelo_soja'])
preco_farelo_soja['date'] = pd.to_datetime(preco_farelo_soja['date'])
preco_farelo_soja.set_index('date', inplace=True)
preco_farelo_soja = preco_farelo_soja.resample('Y').sum()
preco_farelo_soja = preco_farelo_soja.reset_index()
preco_farelo_soja['year'] = preco_farelo_soja['date'].dt.year
preco_farelo_soja = preco_farelo_soja.drop(columns=['date'])
preco_farelo_soja = preco_farelo_soja.set_index('year')

# %% [markdown]
# Preço do Milho por Tonelada

# %%
preco_milho = pd.read_excel('preco_milho.xls', names = ['date','preco_milho'])
preco_milho['date'] = pd.to_datetime(preco_milho['date'])
preco_milho.set_index('date', inplace=True)
preco_milho = preco_milho.resample('Y').sum()
preco_milho = preco_milho.reset_index()
preco_milho['year'] = preco_milho['date'].dt.year
preco_milho = preco_milho.drop(columns=['date'])
preco_milho = preco_milho.set_index('year')

# %% [markdown]
# Criação da Base Analítica

# %%
forecast_final = pd.concat([forecast_anual,pib_,pib_China_,pib_Espanha_,pib_Holanda_,pib_Iran_,preco_soja,preco_farelo_soja,preco_milho], axis=1, sort=True)
forecast_final = forecast_final.astype('int64')

# %%
forecast_final.head()
# Out:
#                      date         usd      tons    PIB_Brasil      PIB_China  \
# year
# 1997   883526400000000000  6443798431  22156986  883199625324   961603952951
# 1998   915062400000000000  5347976808  23469028  863723411632  1029043097554
# 1999   946598400000000000  4308318434  23876364  599388579985  1093997267271
# 2000   978220800000000000  4431648402  22998891  655420645476  1211346869605
# 2001  1009756800000000000  6282705307  36091625  559372276081  1339395718865
#
#        PIB_Espanha   PIB_Holanda      PIB_Iran  preco_soja  preco_farelo_soja  \
# year
# 1997  590077272727  416812740004  113919163421         837               3097
# 1998  619214834614  438008220395  110276913362         893               2096
# 1999  634693160025  446898572341  113848450088         699               1830
# 2000  596877648793  416442786069  109591707802         732               2246
# 2001  627286800894  431213422818  126878750295         675               2167
#
#       preco_milho
# ...

# %%
forecast_final.describe().astype('int64')
# Out:
#                usd       tons     PIB_Brasil       PIB_China    PIB_Espanha  \
# count           23         23             23              23             23
# mean   23847029520   70839490  1463519599007   5828955003725  1141110811129
# std    17297705312   42709858   726935026659   4638501565830   345570524253
# min     4308318434   22156986   507962487700    961603952951   590077272727
# 25%     7839215195   39402977   766520032824   1565418990371   805443207575
# 50%    20936587031   56290187  1667019783585   4594307032660  1259343871534
# 75%    42227114815  108950361  1974156790086  10023044578126  1407106279290
# max    50756763073  147906550  2616200980392  14342903006431  1625224842536
#
#         PIB_Holanda      PIB_Iran  preco_soja  preco_farelo_soja  preco_milho
# count            23            23          23                 23           23
# mean   717400767138  319443932244        1280               3592         1884
# ...

# %% [markdown]
# Nesse ponto iremos testar se os dados são aucorrelacionados ou não. Fazendo isso podemos escolher melhor o modelo a ser usado.
#
# O teste escolhido é o Durbin-Watson que indica uma autocorrelação entre os residuais em uma regressão. As hipóteses são:
# H0 (hipótese Nula): Há correlação entre os residuais.
# HA (hipótese Alternativa): Os residuais são auto correlacionados.
# O teste varia entre 0 a 4 e a interpretação é a seguinte:
# O teste estatístico no valor de 2 indica uma não correlação serial. O teste gera resultados próximos de 0, há evidências de uma autocorrelação positiva. O teste gera resultados próximos de 4, há evidências de uma autocorrelação negativa.
# Valores entre 1.5 e 2.5 são considerados normais.
# Como podemos observar, no caso dos dados em análise, obtivemos um valor de teste de 2.52, ou seja, está dentro do range entre 1,5 e 2,5, ou seja, mais distante de zero. Por isso, está tendendo a aceitarmos a hipótese nula, de que os dados não são auto correlacionados.
#
# Segundo o teste de Durbin, não temos uma autocorrelação na base.

# %%
from statsmodels.formula.api import ols

#fit multiple linear regression model
model = ols('tons ~ usd + PIB_Brasil + PIB_China + PIB_Espanha + PIB_Holanda + PIB_Iran + preco_soja + preco_farelo_soja + preco_milho', data=forecast_final).fit()

#view model summary
print(model.summary())

from statsmodels.stats.stattools import durbin_watson

#perform Durbin-Watson test
durbin_watson(model.resid)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   tons   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     288.8
# Date:                Sun, 20 Dec 2020   Prob (F-statistic):           1.76e-13
# Time:                        17:03:48   Log-Likelihood:                -375.25
# No. Observations:                  23   AIC:                             770.5
# Df Residuals:                      13   BIC:                             781.9
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          5.807e+07   1.25e+07      4.662      0.000    3.12e+07     8.5e+07
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 10))


plt.hist(forecast_final['tons'], bins='auto', alpha=0.7, rwidth=0.85)
plt.title(" Histograma da variável 'rtfpna' ", size=20, pad=15)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Frequência', fontsize=20, labelpad=20);



fig, ax = plt.subplots(figsize=(20, 10))
forecast_final['tons'].plot(kind='kde')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Valores TFP', fontsize=20, labelpad=20)
plt.ylabel('Densidade', fontsize=20, labelpad=20);

pyplot.show()

# %% [markdown]
# ## Modelo ARIMA

# %%
rcParams['figure.figsize'] = 10, 10
decomposition = sm.tsa.seasonal_decompose(forecast_final['tons'], model='additive',period = 11)
fig = decomposition.plot()
plt.show()

# %%
forecast_final['date'] = forecast_anual['date'] 
forecast_final['date'] = pd.to_datetime(forecast_final['date'])
fore = forecast_final[['date','tons']]
fore = fore.set_index('date')

# %% [markdown]
# Podemos observar uma fraca sazonalidade entre os dados.

# %% [markdown]
# Os melhores hiper parâmetros são p:1, d:0, q:0 com RMSE de 0.027. Também foi usado 66% dos dados para treino e 34% para teste.

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(fore.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=69962732.364
# ARIMA(0, 0, 1) RMSE=43873898.389
# ARIMA(0, 0, 2) RMSE=37672103.953
# ARIMA(0, 1, 0) RMSE=17036089.822
# ARIMA(0, 1, 1) RMSE=17594314.573
# ARIMA(0, 1, 2) RMSE=17218585.498
# ARIMA(0, 2, 0) RMSE=23438381.316
# ARIMA(0, 2, 1) RMSE=16005654.558
# ARIMA(0, 2, 2) RMSE=16454377.887
# ARIMA(1, 0, 0) RMSE=18015186.916
# ARIMA(1, 0, 1) RMSE=19147556.996
# ARIMA(1, 0, 2) RMSE=20779201.405
# ARIMA(1, 1, 0) RMSE=17580272.663
# ARIMA(1, 1, 1) RMSE=16304355.144
# ARIMA(1, 1, 2) RMSE=17607875.866
# ARIMA(1, 2, 0) RMSE=18530323.491
# ARIMA(1, 2, 1) RMSE=15883863.488
# ARIMA(1, 2, 2) RMSE=16700973.687
# ARIMA(2, 0, 0) RMSE=19114853.350
# ARIMA(2, 0, 1) RMSE=20452369.796
# ARIMA(2, 0, 2) RMSE=21193125.032
# ARIMA(2, 1, 0) RMSE=17716756.730
# ARIMA(2, 1, 1) RMSE=16737054.135
# ARIMA(2, 2, 0) RMSE=17658251.874
# ARIMA(2, 2, 1) RMSE=18437436.252
# ARIMA(2, 2, 2) RMSE=18605624.804
# ARIMA(4, 0, 0) RMSE=19677354.421
# ARIMA(4, 0, 1) RMSE=20585340.196
# ...

# %% [markdown]
# Nesta etapa foi usado os melhores hiper parâmetros selecionados logo acima para a criação do modelo ARIMA. Os resultados completos são mostrados na célula abaixo.

# %%
mod = sm.tsa.statespace.SARIMAX(fore,
                                order=(1, 2, 1),
                                seasonal_order=(1, 2, 1, 5),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4412    3.9e+05  -1.13e-06      1.000   -7.65e+05    7.65e+05
# ma.L1         -0.8567   8.54e+04     -1e-05      1.000   -1.67e+05    1.67e+05
# ar.S.L5       -1.2578   1.16e+05  -1.09e-05      1.000   -2.27e+05    2.27e+05
# ma.S.L5       -0.2756   1.85e+05  -1.49e-06      1.000   -3.62e+05    3.62e+05
# sigma2      7.725e+14      0.000   2.91e+18      0.000    7.73e+14    7.73e+14
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2010-12-31'), dynamic=False)
pred_ci = pred.conf_int()

ax = fore['1997':].plot(label='Valor observado', marker='o')

pred.predicted_mean.plot(ax=ax, label='Previsão de tons', alpha=.7, figsize=(14, 7), marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Anos',fontsize=20)
ax.set_ylabel('Toneladas',fontsize=20)
plt.legend()




plt.title('Previsão de toneladas exportadas', size=20, pad=15)



plt.yticks([0, 0.5e08, 1e08,1.5e08,2e08], 
          ['0', '50 Milhões', '100 Milhão', '150 Milhões', '200 Milhões'],
          fontsize=18);



plt.xticks(['2000-12-31',
           '2010-12-31', '2019-12-31'], 
           
         ['2000','2010','2019'], fontsize=18)


plt.xticks(rotation=45);

plt.legend(fontsize=18);

# %%
#fig, ax = plt.subplots(figsize=(20, 10))

pred_uc = results.get_forecast(steps=11, marker='o')
pred_ci = pred_uc.conf_int()

ax =fore.plot(label='Valor observado', figsize=(14, 7), marker='o')
pred_uc.predicted_mean.plot(ax=ax, label='Previsão em 10 anos', marker='o')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Anos')
ax.set_ylabel('Toneladas',fontsize=10)
plt.legend()



plt.yticks(fontsize=20);
           


plt.xticks(fontsize=20)


plt.title('Previsão de toneladas exportadas nos próximos 10 anos', size=20, pad=15)


plt.yticks([0, 1e08, 2e08,3e08,4e08,5e08,6e08,7e08], 
          ['0', '100 Milhões', '200 Milhão', '300 Milhões', '400 Milhões', '500 Milhões', '600 Milhões', '700 Milhões'],
          fontsize=18);







plt.xticks(rotation=45);

plt.legend(fontsize=18);


plt.show()

# %%
forecast_final['date'] = forecast_anual['date'] 
forecast_final['date'] = pd.to_datetime(forecast_final['date'])
fore = forecast_final[['date','tons']]
fore = fore.set_index('date')

# %%
df1 = fore
df2 = pd.DataFrame(pred_uc.predicted_mean)
df2 = df2.reset_index()
df2 = df2.rename(columns={"index": "date","predicted_mean":"tons"})
df2['tons'] = df2['tons'].astype('int64')
df2['date'] = pd.to_datetime(df2['date'])
df2=df2.set_index('date')

# %%
frames = [df1, df2]

previsão_11_anos = pd.concat(frames,axis=0)

# %% [markdown]
# Abaixo encontra-se a previsão de toneladas nos próximos 11 anos.

# %%
previsão_11_anos
# Out:
#                  tons
# date
# 1997-12-31   22156986
# 1998-12-31   23469028
# 1999-12-31   23876364
# 2000-12-31   22998891
# 2001-12-31   36091625
# 2002-12-31   36970849
# 2003-12-31   41835106
# 2004-12-31   44453825
# 2005-12-31   46688463
# 2006-12-31   49588239
# 2007-12-31   56290187
# 2008-12-31   51367646
# 2009-12-31   56531098
# 2010-12-31   62098379
# 2011-12-31   63726442
# 2012-12-31   95055235
# 2013-12-31  112327636
# 2014-12-31  105573087
# 2015-12-31  125288676
# 2016-12-31  118655859
# 2017-12-31  142012922
# 2018-12-31  144345193
# 2019-12-31  147906550
# 2020-12-31  169808237
# 2021-12-31  167218097
# 2022-12-31  227156418
# 2023-12-31  263236884
# 2024-12-31  253002925
# 2025-12-31  294608365
# 2026-12-31  283667078
# 2027-12-31  326959589
# 2028-12-31  338478505
# 2029-12-31  347655652
# 2030-12-31  389832840

# %% [markdown]
# Comportamento das Variáveis

# %%
# Plot
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = forecast_final[forecast_final.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(forecast_final_.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag= 6
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(forecast_final_, variables = forecast_final_.columns)
# Out:
#                       usd_x  tons_x  PIB_Brasil_x  PIB_China_x  PIB_Espanha_x  \
# usd_y                1.0000     0.0        0.0000          0.0            0.0
# tons_y               0.0000     1.0        0.0000          0.0            0.0
# PIB_Brasil_y         0.0010     0.0        0.9997          0.0            0.0
# PIB_China_y          0.0000     0.0        0.0000          1.0            0.0
# PIB_Espanha_y        0.0000     0.0        0.0175          0.0            1.0
# PIB_Holanda_y        0.0000     0.0        0.0362          0.0            0.0
# PIB_Iran_y           0.0000     0.0        0.0001          0.0            0.0
# preco_soja_y         0.0107     0.0        0.0000          0.0            0.0
# preco_farelo_soja_y  0.0000     0.0        0.0000          0.0            0.0
# preco_milho_y        0.0027     0.0        0.0000          0.0            0.0
#
#                      PIB_Holanda_x  PIB_Iran_x  preco_soja_x  \
# ...

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(forecast_final_)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# usd    ::  nan       > 219.4051  =>   False
# tons   ::  nan       > 179.5199  =>   False
# PIB_Brasil ::  581.92    > 143.6691  =>   True
# PIB_China ::  137.0     > 111.7797  =>   True
# PIB_Espanha ::  68.45     > 83.9383   =>   False
# PIB_Holanda ::  41.62     > 60.0627   =>   False
# PIB_Iran ::  23.08     > 40.1749   =>   False
# preco_soja ::  11.5      > 24.2761   =>   False
# preco_farelo_soja ::  5.37      > 12.3212   =>   False
# preco_milho ::  0.3       > 4.1296    =>   False

# %%
from sklearn.preprocessing import StandardScaler

# %%
forecast_final_  = forecast_final.drop(['date'], axis = 1)

# %% [markdown]
# # Modelo de Regreção Linear

# %%
# Padronizando
zscore  = StandardScaler()
forecast_final_normalizado = zscore.fit_transform(forecast_final_)
forecast_final_normalizado = pd.DataFrame(forecast_final_normalizado, columns = ['usd', 'tons', 'PIB_Brasil', 'PIB_China',
                                                                                 'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                                                                                 'preco_soja', 'preco_farelo_soja', 
                                                                                 'preco_milho'])
# Obtendo o conjunto de dados X e o vetor de alvos y
X, y = forecast_final_normalizado[['usd', 'PIB_Brasil', 'PIB_China',
                                   'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                                   'preco_soja', 'preco_farelo_soja', 
                                   'preco_milho']], forecast_final_normalizado['tons']


from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)


#Métrica de avaliação
r_sq = model.score(X, y)
#print('Coeficiente de determinação:', r_sq)

# Fazendo a predição com todos os dados 
y_pred = model.predict(X)

# print('Coeficiente linear (intercept):', model.intercept_)

# print('Coeficiente angular (Taxa de variação):', model.coef_)


#Predizendo valores novos 
# y_pred_hand = model.intercept_ + model.coef_[1] * 200
# print('O valor de venda previsto é:', y_pred_hand, sep='\n')



modelo_norma_X_y = pd.concat([X, y], axis=1, sort=False)



SS_Residual = sum((y-y_pred)**2) 

SS_Total = sum((y-np.mean(y))**2)    

r_squared = 1 - (float(SS_Residual))/SS_Total

adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)


VIF = 1/1-r_squared
#print('O valor de VIF para o modelo é:', VIF)


# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns



import statsmodels.api as sm
#Calculando o sumário das estatísticas 
X_sm = sm.add_constant(X) # adicionando valores de 1's nos dados
results = sm.OLS(y, X_sm).fit()
results.summary()


X_sm = sm.add_constant(X)

mod_fit = sm.OLS(y, X_sm).fit()
res = mod_fit.resid # residuals

res = mod_fit.resid




forecast_final_normalizado['Predição'] = y_pred

forecast_final_normalizado_s = forecast_final_normalizado[['usd', 'PIB_Brasil', 'PIB_China',
                       'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                       'preco_soja', 'preco_farelo_soja', 
                        'preco_milho','tons']]


forecast_final_normalizado_p = forecast_final_normalizado[['usd', 'PIB_Brasil', 'PIB_China',
                                                           'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                                                           'preco_soja', 'preco_farelo_soja', 
                                                           'preco_milho','Predição']]

inversed_s = zscore.inverse_transform(forecast_final_normalizado_s)
inversed_s = pd.DataFrame(inversed_s, columns = ['usd_s', 'PIB_Brasil_s', 'PIB_China_s',
                                                 'PIB_Espanha_s', 'PIB_Holanda_s', 'PIB_Iran_s',
                                                 'preco_soja_s', 'preco_farelo_soja_s', 
                                                 'preco_milho_s','tons'])

inversed_p = zscore.inverse_transform(forecast_final_normalizado_p)
inversed_p = pd.DataFrame(inversed_p, columns = ['usd', 'PIB_Brasil', 'PIB_China',
                                                  'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                                                 'preco_soja', 'preco_farelo_soja', 
                                                 'preco_milho','Predição'])

s = pd.concat([inversed_s, inversed_p], axis=1, sort=False)


modelo_exp = s[['usd', 'PIB_Brasil', 'PIB_China',
                       'PIB_Espanha', 'PIB_Holanda', 'PIB_Iran',
                       'preco_soja', 'preco_farelo_soja', 
                        'preco_milho','tons', 'Predição']]

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   tons   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     288.8
# Date:                Sun, 20 Dec 2020   Prob (F-statistic):           1.76e-13
# Time:                        22:17:41   Log-Likelihood:                 28.347
# No. Observations:                  23   AIC:                            -36.69
# Df Residuals:                      13   BIC:                            -25.34
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
modelo_exp
# Out:
#              usd    PIB_Brasil     PIB_China   PIB_Espanha   PIB_Holanda  \
# 0   6.443798e+09  3.674376e+07  7.007198e+11 -1.567422e+12  5.991479e+11
# 1   5.347977e+09  3.559946e+07  7.112887e+11 -1.176316e+12  6.373636e+11
# 2   4.308318e+09  2.006891e+07  7.214682e+11 -9.685549e+11  6.533929e+11
# 3   4.431648e+09  2.336098e+07  7.398589e+11 -1.476143e+12  5.984809e+11
# 4   6.282705e+09  1.771782e+07  7.599265e+11 -1.067969e+12  6.251125e+11
# 5   6.891111e+09  1.469732e+07  7.804806e+11 -1.955204e+10  6.979550e+11
# 6   8.787319e+09  1.765599e+07  8.102159e+11  2.666307e+12  8.911986e+11
# 7   1.100713e+10  2.417742e+07  8.564569e+11  4.835439e+12  1.032517e+12
# 8   1.101670e+10  3.723908e+07  9.082707e+11  5.992375e+12  1.082859e+12
# 9   1.199361e+10  4.993039e+07  9.813271e+11  7.415966e+12  1.169851e+12
# 10  1.523906e+10  6.693620e+07  1.106421e+12  1.027215e+13  1.375648e+12
# 11  2.121870e+10  8.448818e+07  1.270028e+12  1.232709e+13  1.556879e+12
# ...

# %% [markdown]
# Gráfico de Dispersão

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='usd', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='PIB_Brasil', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='PIB_China', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='PIB_Espanha', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='PIB_Iran', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='PIB_Holanda', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='preco_soja', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='preco_farelo_soja', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()

# %%
#Plotando gráfico de dispersão

modelo_exp.plot(x='preco_milho', y='tons', style='o')  
plt.title('Gráfico de dispersão')  
#plt.xlabel('Espaco')  
#plt.ylabel('Vendas (Valores em milhares)')  
plt.show()
